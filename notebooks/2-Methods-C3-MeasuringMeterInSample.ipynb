# %% [markdown]
# # Rhyme

# %%
# !pip install -r ../requirements.txt
import sys
sys.path.append('../')
from generative_formalism import *

# %%
txt = """
From fairest creatures we desire increase,
That thereby beauty’s rose might never die,
But as the riper should by time decease,
His tender heir might bear his memory;
But thou, contracted to thine own bright eyes,
Feed’st thy light’s flame with self-substantial fuel,
Making a famine where abundance lies,
Thyself thy foe, to thy sweet self too cruel.
Thou that art now the world’s fresh ornament
And only herald to the gaudy spring,
Within thine own bud buriest thy content,
And, tender churl, mak’st waste in niggarding.
   Pity the world, or else this glutton be,
   To eat the world’s due, by the grave and thee.
"""

# %%
documentation(parse_text)

parses = parse_text(txt)
parses.to_html()
# Out:
# ##### `parse_text`
#
# ```md
# Parse poem text using Prosodic for meter and stress analysis.
#
#     Uses the Prosodic library to analyze the metrical structure of the input text,
#     parsing at the line level with single-threaded processing.
#
#     Parameters
#     ----------
#     txt : str
#         The poem text to parse for metrical analysis.
#
#     Returns
#     -------
#     prosodic.Text
#         Parsed Prosodic Text object containing meter and stress information.
#
#     Calls
#     -----
#     - prosodic.Text(txt).parse(parse_unit='line', num_proc=1).best
#
# ```
# ----
#                                                                      1.19it/s]
# <ol class="parselist"><li><style>
#
# .miniquote { margin-left:0em;margin-top:.5em;font-family:monospace; font-size:.8em;}
# .parse { line-height:2.5em; letter-spacing:.1em;}
# .parselist { list-style-type: none; }
# .parselist li { padding-left:2em;}
# .parselist li:nth-child(5n) { list-style-type: decimal; }
# .parse { text-decoration-offset:5px; }
#
# .viol_y { text-decoration-color:#f43838; color: #f43838; }
# .mtr_s { text-decoration: overline; }
# .str_s { font-weight:600; }
# .parselist > li:first-of-type { list-style-type: decimal; }
# .parselist > li:last-of-type { list-style-type: decimal; }
# </style><div class="parse"><span class="mtr_w str_w viol_n">From</span> <span class="mtr_s str_s viol_n">fai</span><span class="mtr_w str_w viol_n">rest</span> <span class="mtr_s str_s viol_n">crea</span><span class="mtr_w str_w viol_n">tures</span> <span class="mtr_s str_w viol_y">we</span> <span class="mtr_w str_w viol_n">de</span><span class="mtr_s str_s viol_n">sire</span> <span class="mtr_w str_w viol_n">in</span><span class="mtr_s str_s viol_n">crease</span>,</div></li>
# <li><style>
#
# .miniquote { margin-left:0em;margin-top:.5em;font-family:monospace; font-size:.8em;}
# .parse { line-height:2.5em; letter-spacing:.1em;}
# .parselist { list-style-type: none; }
# .parselist li { padding-left:2em;}
# .parselist li:nth-child(5n) { list-style-type: decimal; }
# .parse { text-decoration-offset:5px; }
#
# .viol_y { text-decoration-color:#f43838; color: #f43838; }
# .mtr_s { text-decoration: overline; }
# .str_s { font-weight:600; }
# .parselist > li:first-of-type { list-style-type: decimal; }
# .parselist > li:last-of-type { list-style-type: decimal; }
# </style><div class="parse">
# <span class="mtr_w str_w viol_n">That</span> <span class="mtr_s str_s viol_n">the</span><span class="mtr_w str_s viol_y">reby</span> <span class="mtr_s str_s viol_n">bea</span><span class="mtr_w str_w viol_n">uty's</span> <span class="mtr_s str_s viol_n">rose</span> <span class="mtr_w str_w viol_n">might</span> <span class="mtr_s str_s viol_n">ne</span><span class="mtr_w str_w viol_n">ver</span> <span class="mtr_s str_s viol_n">die</span>,</div></li>
# <li><style>
#
# .miniquote { margin-left:0em;margin-top:.5em;font-family:monospace; font-size:.8em;}
# .parse { line-height:2.5em; letter-spacing:.1em;}
# .parselist { list-style-type: none; }
# .parselist li { padding-left:2em;}
# .parselist li:nth-child(5n) { list-style-type: decimal; }
# .parse { text-decoration-offset:5px; }
#
# .viol_y { text-decoration-color:#f43838; color: #f43838; }
# .mtr_s { text-decoration: overline; }
# .str_s { font-weight:600; }
# .parselist > li:first-of-type { list-style-type: decimal; }
# .parselist > li:last-of-type { list-style-type: decimal; }
# </style><div class="parse">
# <span class="mtr_w str_w viol_n">But</span> <span class="mtr_s str_w viol_y">as</span> <span class="mtr_w str_w viol_n">the</span> <span class="mtr_s str_s viol_n">riper</span> <span class="mtr_w str_w viol_n">should</span> <span class="mtr_w str_w viol_n">by</span> <span class="mtr_s str_s viol_n">time</span> <span class="mtr_w str_w viol_n">de</span><span class="mtr_s str_s viol_n">cease</span>,</div></li>
# <li><style>
#
# .miniquote { margin-left:0em;margin-top:.5em;font-family:monospace; font-size:.8em;}
# .parse { line-height:2.5em; letter-spacing:.1em;}
# .parselist { list-style-type: none; }
# .parselist li { padding-left:2em;}
# .parselist li:nth-child(5n) { list-style-type: decimal; }
# .parse { text-decoration-offset:5px; }
#
# .viol_y { text-decoration-color:#f43838; color: #f43838; }
# .mtr_s { text-decoration: overline; }
# .str_s { font-weight:600; }
# .parselist > li:first-of-type { list-style-type: decimal; }
# .parselist > li:last-of-type { list-style-type: decimal; }
# </style><div class="parse">
# <span class="mtr_w str_w viol_n">His</span> <span class="mtr_s str_s viol_n">ten</span><span class="mtr_w str_w viol_n">der</span> <span class="mtr_s str_s viol_n">heir</span> <span class="mtr_w str_w viol_n">might</span> <span class="mtr_s str_s viol_n">bear</span> <span class="mtr_w str_w viol_n">his</span> <span class="mtr_s str_s viol_n">me</span><span class="mtr_w str_w viol_n">mo</span><span class="mtr_s str_w viol_y">ry</span>;</div></li>
# <li><style>
#
# .miniquote { margin-left:0em;margin-top:.5em;font-family:monospace; font-size:.8em;}
# .parse { line-height:2.5em; letter-spacing:.1em;}
# .parselist { list-style-type: none; }
# .parselist li { padding-left:2em;}
# .parselist li:nth-child(5n) { list-style-type: decimal; }
# .parse { text-decoration-offset:5px; }
#
# .viol_y { text-decoration-color:#f43838; color: #f43838; }
# .mtr_s { text-decoration: overline; }
# .str_s { font-weight:600; }
# .parselist > li:first-of-type { list-style-type: decimal; }
# .parselist > li:last-of-type { list-style-type: decimal; }
# </style><div class="parse">
# <span class="mtr_w str_w viol_n">But</span> <span class="mtr_w str_w viol_n">thou</span>, <span class="mtr_s str_s viol_n">con</span><span class="mtr_w str_w viol_n">trac</span><span class="mtr_s str_w viol_y">ted</span> <span class="mtr_w str_w viol_n">to</span> <span class="mtr_w str_w viol_n">thine</span> <span class="mtr_s str_s viol_n">own</span> <span class="mtr_w str_s viol_y">bright</span> <span class="mtr_s str_s viol_n">eyes</span>,</div></li>
# <li><style>
#
# .miniquote { margin-left:0em;margin-top:.5em;font-family:monospace; font-size:.8em;}
# .parse { line-height:2.5em; letter-spacing:.1em;}
# .parselist { list-style-type: none; }
# .parselist li { padding-left:2em;}
# .parselist li:nth-child(5n) { list-style-type: decimal; }
# .parse { text-decoration-offset:5px; }
#
# .viol_y { text-decoration-color:#f43838; color: #f43838; }
# .mtr_s { text-decoration: overline; }
# .str_s { font-weight:600; }
# .parselist > li:first-of-type { list-style-type: decimal; }
# .parselist > li:last-of-type { list-style-type: decimal; }
# </style><div class="parse">
# <span class="mtr_s str_s viol_n">Feed'st</span> <span class="mtr_w str_w viol_n">thy</span> <span class="mtr_s str_s viol_n">light's</span> <span class="mtr_s str_s viol_y">flame</span> <span class="mtr_w str_w viol_n">with</span> <span class="mtr_s str_s viol_n">self</span>-<span class="mtr_w str_w viol_n">subs</span><span class="mtr_s str_s viol_n">tan</span><span class="mtr_w str_w viol_n">tial</span> <span class="mtr_s str_s viol_n">fu</span><span class="mtr_w str_w viol_n">el</span>,</div></li>
# <li><style>
#
# .miniquote { margin-left:0em;margin-top:.5em;font-family:monospace; font-size:.8em;}
# .parse { line-height:2.5em; letter-spacing:.1em;}
# .parselist { list-style-type: none; }
# .parselist li { padding-left:2em;}
# .parselist li:nth-child(5n) { list-style-type: decimal; }
# .parse { text-decoration-offset:5px; }
#
# .viol_y { text-decoration-color:#f43838; color: #f43838; }
# .mtr_s { text-decoration: overline; }
# .str_s { font-weight:600; }
# .parselist > li:first-of-type { list-style-type: decimal; }
# .parselist > li:last-of-type { list-style-type: decimal; }
# </style><div class="parse">
# <span class="mtr_s str_s viol_n">Ma</span><span class="mtr_w str_w viol_n">king</span> <span class="mtr_w str_w viol_y">a</span> <span class="mtr_s str_s viol_n">fa</span><span class="mtr_w str_w viol_n">mine</span> <span class="mtr_s str_s viol_n">where</span> <span class="mtr_w str_w viol_n">a</span><span class="mtr_s str_s viol_n">bun</span><span class="mtr_w str_w viol_n">dance</span> <span class="mtr_s str_s viol_n">lies</span>,</div></li>
# <li><style>
#
# .miniquote { margin-left:0em;margin-top:.5em;font-family:monospace; font-size:.8em;}
# .parse { line-height:2.5em; letter-spacing:.1em;}
# .parselist { list-style-type: none; }
# .parselist li { padding-left:2em;}
# .parselist li:nth-child(5n) { list-style-type: decimal; }
# .parse { text-decoration-offset:5px; }
#
# .viol_y { text-decoration-color:#f43838; color: #f43838; }
# .mtr_s { text-decoration: overline; }
# .str_s { font-weight:600; }
# .parselist > li:first-of-type { list-style-type: decimal; }
# .parselist > li:last-of-type { list-style-type: decimal; }
# </style><div class="parse">
# <span class="mtr_w str_w viol_n">Thy</span><span class="mtr_s str_s

# %%
documentation(get_parses_for_txt)
parses_df = get_parses_for_txt(txt)
parses_df
# Out:
# ##### `get_parses_for_txt`
#
# ```md
# Get prosodic parses for a text, with caching and optional postprocessing.
#
#     Retrieves cached prosodic parse data if available and not forced to regenerate.
#     If no cached data exists or force=True, parses the text using Prosodic and caches
#     the result. Optionally postprocesses the parse data into rhythm measurements.
#
#     Parameters
#     ----------
#     txt : str
#         The poem text to parse.
#     stash : HashStash, default=STASH_RHYTHM
#         Cache storage for parsed data.
#     force : bool, default=False
#         If True, re-parse even if cached data exists.
#     postprocess : bool, default=False
#         If True, apply postprocessing to extract rhythm measurements.
#
#     Returns
#     -------
#     pd.DataFrame or dict
#         Raw parse DataFrame if postprocess=False, or processed rhythm measurements
#         dict if postprocess=True. Returns empty DataFrame if parsing fails.
#
#     Calls
#     -----
#     - parse_text(txt) [if no cached data or force=True]
#     - postprocess_parses_data(odf) [if postprocess=True]
#
# ```
# ----
#                                                                                                                                                                                                   parse_score  \
# stanza_num line_num line_txt                                           linepart_num parse_rank parse_txt                                          parse_meter parse_stress sent_num sentpart_num
# 1          1        From fairest creatures we desire increase,         1            1          from FAI rest CREA tures WE de SIRE in CREASE      -+-+-+-+-+  -+-+---+-+   1        1                     1.0
#            2        That thereby beauty's rose might never die,        2            1          that THE reby BEA uty's ROSE might NE ver DIE      -+-+-+-+-+  -+++-+-+-+   1        2                     1.0
#            3        But as the riper should by time decease,           3            1          but AS the RIPER should.by TIME de CEASE           -+-+--+-+   ---+--+-+    1        3                     1.0
#            4        His tender heir might bear his memory;             4            1          his TEN der HEIR might BEAR his ME mo RY           -+-+-+-+-+  -+-+-+-+--   1        4                     1.0
#            5        But thou, contracted to thine own bright eyes,     5            1          but.thou CON trac TED to.thine OWN bright EYES     --+-+--+-+  --+----+++   1        5                     2.0
#            6        Feed'st thy light's flame with self-substantial... 7            1          FEED'ST thy LIGHT'S.FLAME with SELF subs TAN ti... +-++-+-+-+- +-++-+-+-+-  1        7                     1.0
#            7        Making a famine where abundance lies,              8            1          MA king.a FA mine WHERE a BUN dance LIES           +--+-+-+-+  +--+-+-+-+   1        8                     1.0
#            8        Thyself thy foe, to thy sweet self too cruel.      9            1          thy SELF thy FOE to.thy SWEET self TOO cruel       -+-+--+-+-  -+-+--++++   1        9                     2.0
#            9        Thou that art now the world's fresh ornament       11           1          thou THAT art NOW the WORLD'S fresh OR na MENT     -+-+-+-+-+  -+-+-+++--   2        11                    2.0
#            10       And only herald to the gaudy spring,               12           1          and ON ly HE rald TO the GAU dy SPRING             -+-+-+-+-+  -+-+---+-+   2        11                    1.0
#            11       Within thine own bud buriest thy content,          13           1          wit HIN thine OWN bud BU ri EST thy CON tent       -+-+-+-+-+- -+-+++---+-  2        12                    2.0
#            12       And, tender churl, mak'st waste in niggarding.     14           1          and TEN der CHURL mak'st WASTE in NIG garding      -+-+-+-+-   -+-+++-+-    2        13                    1.0
#            13       Pity the world, or else this glutton be,           17           1          PI ty.the WORLD or ELSE this GLUT ton BE           +--+-+-+-+  +--+-+-+-+   3        16                    1.0
#            14       To eat the world's due, by the grave and thee.     19           1          to EAT the WORLD'S.DUE by.the GRAVE and.thee       -+-++--+--  -+-++--+--   3        18                    1.0
#
#                                                                                                                                                                                                   parse_num_viols  \
# stanza_num line_num line_txt                                           linepart_num parse_rank parse_txt                                          parse_meter parse_stress sent_num sentpart_num
# 1          1        From fairest creatures we desire increase,         1            1          from FAI rest CREA tures WE de SIRE in CREASE      -+-+-+-+-+  -+-+---+-+   1        1                           1
#            2        That thereby beauty's rose might never die,        2            1          that THE reby BEA uty's ROSE might NE ver DIE      -+-+-+-+-+  -+++-+-+-+   1        2                           1
#            3        But as the riper should by time decease,           3            1          but AS the RIPER should.by TIME de CEASE           -+-+--+-+   ---+--+-+    1        3                           1
#            4        His tender heir might bear his memory;             4            1          his TEN der HEIR might BEAR his ME mo RY           -+-+-+-+-+  -+-+-+-+--   1        4                           1
#            5        But thou, contracted to thine own bright eyes,     5            1          but.thou CON trac TED to.thine OWN bright EYES     --+-+--+-+  --+----+++   1        5                           2
#            6        Feed'st thy light's flame with self-substantial... 7            1          FEED'ST thy LIGHT'S.FLAME with SELF subs TAN ti... +-++-+-+-+- +-++-+-+-+-  1        7                           1
#            7        Making a famine where abundance lies,              8            1          MA king.a FA mine WHERE a BUN dance LIES           +--+-+-+-+  +--+-+-+-+   1        8                           1
#            8        Thyself thy foe, to thy sweet self too cruel.      9            1          thy SELF thy FOE to.thy SWEET self TOO cruel       -+-+--+-+-  -+-+--++++   1        9                           2
#            9        Thou that art now the world's fresh ornament       11           1          thou THAT art NOW the WORLD'S fresh OR na MENT     -+-+-+-+-+  -+-+-+++--   2        11                          2
#            10       And only herald to the gaudy spring,               12           1          and ON ly HE rald TO the GAU dy SPRING             -+-+-+-+-+  -+-+---+-+   2        11                          1
#            11       Within thine own bud buriest thy content,          13           1          wit HIN thine OWN bud BU ri EST thy CON tent       -+-+-+-+-+- -+-+++---+-  2        12                          2
#            12       And, tender churl, mak'st waste in niggarding.     14           1          and TEN der CHURL mak'st WASTE in NIG garding      -+-+-+-+-   -+-+++-+-    2        13                          1
#            13       Pity the world, or else this glutton be,           17           1          PI ty.the WORLD or ELSE this GLUT ton BE           +--+-+-+-+  +--+-+-+-+   3        16                          1
#            14       To eat the world's due, by the grave and thee.     19           1          to EAT the WORLD'S.DUE by.the GRAVE and.thee       -+-++--+--  -+-++--+--   3        18                          1
#
#                                                                                                                                                                                                   parse_ambig  \
# stanza_num line_num line_txt                                           linepart_num parse_rank parse_txt                                          parse_meter parse_stress sent_num sentpart_num
# 1          1        From fairest creatures we desire increase,         1            1          from FAI rest CREA tures WE de SIRE in CREASE      -+-+-+-+-+  -+-+---+-+   1        1                       1
#            2        That thereby beauty's rose might never die,        2            1          that THE reby BEA uty's ROSE might NE ver DIE      -+-+-+-+-+  -+++-+-+-+   1        2                       1
#            3        But as the riper should by time decease,           3            1          but AS the RIPER should.by TIME de CEASE           -+-+--+-+   ---+--+-+    1        3                       2
#            4        His tender heir might bear his memory;             4            1          his TEN der HEIR might BEAR his ME mo RY           -+-+-+-+-+  -+-+-+-+--   1        4                       3
#            5        But thou, contracted to thine own bright eyes,     5            1          but.thou CON trac TED to.thine OWN bright EYES     --+-+--+-+  --+----+++   1        5                       5
#            6        Feed'st thy light's flame with self-substantial... 7            1          FEED'ST thy LIGHT'S.FLAME with SELF subs TAN ti... +-++-+-+-+- +-++-+-+-+-  1        7                       5
#            7        Making a famine where abundance lies,              8            1          MA king.a FA mine WHERE a BUN dance LIES           +--+-+-+-+  +--+-+-+-+   1        8                       4
#            8        Thyself thy foe, to thy sweet self too cruel.      9            1          thy SELF thy FOE to.thy SWEET self TOO cruel       -+-+--+-+-  -+-+--++++   1        9                       7
#            9        Thou that art now the world's fresh ornament       11           1          thou THAT art NOW the WORLD'S fresh OR na MENT     -+-+-+-+-+  -+-+-+++--   2        11                      2
#            10       And only herald to the gaudy spring,               12           1          and ON ly HE rald TO the GAU dy SPRING             -+-+-+-+-+  -+-+---+-+   2        11                      2
#            11       Within thine own bud buriest thy content,          13           1          wit HIN thine OWN bud BU ri EST thy CON tent       -+-+-+-+-+- -+-+++---+-  2        12                      2
#            12       And, tender churl, mak'st waste in niggarding.     14           1          and TEN der CHURL mak'st WASTE in NIG garding      -+-+-+-+-   -+-+++-+-    2        13                      1
#            13       Pity the world, or else this glutton be,           17           1          PI ty.the WORLD or ELSE this GLUT ton BE           +--+-+-+-+  +--+-+-+-+   3        16                      2
#            14       To eat the world's due, by the grave and thee.     19           1          to EAT the WORLD'S.DUE by.the GRAVE and.thee       -+-++--+--  -+-++--+--   3        18                      2
#
#                                                                                                                                                                                                   parse_is_bounded  \
# stanza_num line_num line_txt                                           linepart_num parse_rank parse_txt                                          parse_meter parse_stress sent_num sentpart_num
# 1          1        From fairest creatures we desire increase,         1            1          from FAI rest CREA tures WE de SIRE in CREASE      -+-+-+-+-+  -+-+---+-+   1        1                            0
#            2        That thereby beauty's rose might never die,        2            1          that THE reby BEA uty's ROSE might NE ver DIE      -+-+-+-+-+  -+++-+-+-+   1        2                            0
#            3        But as the riper should by time decease,           3            1          but AS the RIPER should.by TIME de CEASE           -+-+--+-+   ---+--+-+    1        3                            0
#            4        His tender heir might bear his memory;             4            1          his TEN der HEIR might BEAR his ME mo RY           -+-+-+-+-+  -+-+-+-+--   1        4                            0
#            5        But thou, contracted to thine own bright eyes,     5            1          but.thou CON trac TED to.thine OWN bright EYES     --+-+--+-+  --+----+++   1        5                            0
#            6        Feed'st thy light's flame with self-substantial... 7            1          FEED'ST thy LIGHT'S.FLAME with SELF subs TAN ti... +-++-+-+-+- +-++-+-+-+-  1        7                            0
#            7        Making a famine where abundance lies,              8            1          MA king.a FA mine WHERE a BUN dance LIES           +--+-+-+-+  +--+-+-+-+   1        8                            0
#            8        Thyself thy foe, to thy sweet self too cruel.      9            1          thy SELF thy FOE to.thy SWEET self TOO cruel       -+-+--+-+-  -+-+--++++   1        9                            0
#            9        Thou that art now the world's fresh ornament       11           1          thou THAT art NOW the WORLD'S fresh OR na MENT     -+-+-+-+-+  -+-+-+++--   2        11                           0
#            10       And only herald to the gaudy spring,               12           1          and ON ly HE rald TO the GAU dy SPRING             -+-+-+-+-+  -+-+---+-+   2        11                           0
#            11       Within thine own bud buriest thy content,          13           1          wit HIN thine OWN bud BU ri EST thy CON tent       -+-+-+-+-+- -+-+++---+-  2        12                           0
#            12       And, tender churl, mak'st waste in niggarding.     14           1          and TEN der CHURL mak'st WASTE in NIG garding      -+-+-+-+-   -+-+++-+-    2        13                           0
#            13       Pity the world, or else this glutton be,           17           1          PI ty.the WORLD or ELSE this GLUT ton BE           +--+-+-+-+  +--+-+-+-+   3        16                           0
#            14       To eat the world's due, by the grave and thee.     19           1          to EAT the WORLD'S.DUE by.the GRAVE and.thee       -+-++--+--  -+-++--+--   3        18                           0
#
#                                                                                                                                                                                                   parse_num_sylls  \
# stanza_num line_num line_txt                                           linepart_num parse_rank parse_txt                                          parse_meter parse_stress sent_num sentpart_num
# 1          1        From fairest creatures we desire increase,         1            1          from FAI rest CREA tures WE de SIRE in CREASE      -+-+-+-+-+  -+-+---+-+   1        1                          10
#            2        That thereby beauty's rose might never die,        2            1          that THE reby BEA uty's ROSE might NE ver DIE      -+-+-+-+-+  -+++-+-+-+   1        2                          10
#            3        But as the riper should by time decease,           3            1          but AS the RIPER should.by TIME de CEASE           -+-+--+-+   ---+--+-+    1        3                           9
#            4        His tender heir might bear his memory;             4            1          his TEN der HEIR might BEAR his ME mo RY           -+-+-+-+-+  -+-+-+-+--   1        4                          10
#            5        But thou, contracted to thine own bright eyes,     5            1          but.thou CON trac TED to.thine OWN bright EYES     --+-+--+-+  --+----+++   1        5                          10
#            6        Feed'st thy light's flame with self-substantial... 7            1          FEED'ST thy LIGHT'S.FLAME with SELF subs TAN ti... +-++-+-+-+- +-++-+-+-+-  1        7                          11
#            7        Making a famine where abundance lies,              8            1          MA king.a FA mine WHERE a BUN dance LIES           +--+-+-+-+  +--+-+-+-+   1        8                          10
#            8        Thyself thy foe, to thy sweet self too cruel.      9            1          thy SELF thy FOE to.thy SWEET self TOO cruel       -+-+--+-+-  -+-+--++++   1        9                          10
#            9        Thou that art now the world's fresh ornament       11           1          thou THAT art NOW the WORLD'S fresh OR na MENT     -+-+-+-+-+  -+-+-+++--   2        11                         10
#            10       And only herald to the gaudy spring,               12           1          and ON ly HE rald TO the GAU dy SPRING             -+-+-+-+-+  -+-+---+-+   2        11                         10
#            11       Within thine own bud buriest thy content,          13           1          wit HIN thine OWN bud BU ri EST thy CON tent       -+-+-+-+-+- -+-+++---+-  2        12                         11
#            12       And, tender churl, mak'st waste in niggarding.     14           1          and TEN der CHURL mak'st WASTE in NIG garding      -+-+-+-+-   -+-+++-+-    2        13                          9
#            13       Pity the world, or else this glutton be,           17           1          PI ty.the WORLD or ELSE this GLUT ton BE           +--+-+-+-+  +--+-+-+-+   3        16                         10
#            14       To eat the world's due, by the grave and thee.     19           1          to EAT the WORLD'S.DUE by.the GRAVE and.thee       -+-++--+--  -+-++--+--   3        18                         10
#
#                                                                                                                                                                                                   parse_num_words  \
# stanza_num line_num line_txt                                           linepart_num parse_rank parse_txt                                          parse_meter parse_stress sent_num sentpart_num
# 1          1        From fairest creatures we desire increase,         1            1          from FAI rest CREA tures WE de SIRE in CREASE      -+-+-+-+-+  -+-+---+-+   1        1                           6
#            2        That thereby beauty's rose might never die,        2            1          that THE reby BEA uty's ROSE might NE ver DIE      -+-+-+-+-+  -+++-+-+-+   1        2                           7
#            3        But as the riper should by time decease,           3            1          but AS the RIPER should.by TIME de CEASE           -+-+--+-+   ---+--+-+    1        3                           8
#            4        His tender heir might bear his memory;             4            1          his TEN der HEIR might BEAR his ME mo RY           -+-+-+-+-+  -+-+-+-+--   1        4                           7
#            5        But thou, contracted to thine own bright eyes,     5            1          but.thou CON trac TED to.thine OWN bright EYES     --+-+--+-+  --+----+++   1        5                           8
#            6        Feed'st thy light's flame with self-substantial... 7            1          FEED'ST thy LIGHT'S.FLAME with SELF subs TAN ti... +-++-+-+-+- +-++-+-+-+-  1        7                           8
#            7        Making a famine where abundance lies,              8            1          MA king.a FA mine WHERE a BUN dance LIES           +--+-+-+-+  +--+-+-+-+   1        8                           6
#            8        Thyself thy foe, to thy sweet self too cruel.      9            1          thy SELF thy FOE to.thy SWEET self TOO cruel       -+-+--+-+-  -+-+--++++   1        9                           9
#            9        Thou that art now the world's fresh ornament       11           1          thou THAT art NOW the WORLD'S fresh OR na MENT     -+-+-+-+-+  -+-+-+++--   2        11                          8
#            10       And only herald to the gaudy spring,               12           1          and ON ly HE rald TO the GAU dy SPRING             -+-+-+-+-+  -+-+---+-+   2        11                          7
#            11       Within thine own bud buriest thy content,          13           1          wit HIN thine OWN bud BU ri EST thy CON tent       -+-+-+-+-+- -+-+++---+-  2        12                          7
#            12       And, tender churl, mak'st waste in niggarding.     14           1          and TEN der CHURL mak'st WASTE in NIG garding      -+-+-+-+-   -+-+++-+-    2        13                          7
#            13       Pity the world, or else this glutton be,           17           1          PI ty.the WORLD or ELSE this GLUT ton BE           +--+-+-+-+  +--+-+-+-+   3        16                          8
#            14       To eat the world's due, by the grave and thee.     19           1          to EAT the WORLD'S.DUE by.the GRAVE and.thee       -+-++--+--  -+-++--+--   3        18                         10
#
#                                                                                                                                                                                                   *w_peak  \
# stanza_num line_num line_txt                                           linepart_num parse_rank parse_txt                                          parse_meter parse_stress sent_num sentpart_num
# 1          1        From fairest creatures we desire increase,         1            1          from FAI rest CREA tures WE de SIRE in CREASE      -+-+-+-+-+  -+-+---+-+   1        1                 0.0
#            2        That thereby beauty's rose might never die,        2            1          that THE reby BEA uty's ROSE might NE ver DIE      -+-+-+-+-+  -+++-+-+-+   1        2                 0.0
#            3        But as the riper should by time decease,           3            1          but AS the RIPER should.by TIME de CEASE           -+-+--+-+   ---+--+-+    1        3                 0.0
#            4        His tender heir might bear his memory;             4            1          his TEN der HEIR might BEAR his ME mo RY           -+-+-+-+-+  -+-+-+-+--   1        4                 0.0
#            5        But thou, contracted to thine own bright eyes,     5            1          but.thou CON trac TED to.thine OWN bright EYES     --+-+--+-+  --+----+++   1        5                 0.0
#            6        Feed'st thy light's flame with self-substantial... 7            1          FEED'ST thy LIGHT'S.FLAME with SELF subs TAN ti... +-++-+-+-+- +-++-+-+-+-  1        7                 0.0
#            7        Making a famine where abundance lies,              8            1          MA king.a FA mine WHERE a BUN dance LIES           +--+-+-+-+  +--+-+-+-+   1        8                 0.0
#            8        Thyself thy foe, to thy sweet self too cruel.      9            1          thy SELF thy FOE to.thy SWEET self TOO cruel       -+-+--+-+-  -+-+--++++   1        9                 0.0
#            9        Thou that art now the world's fresh ornament       11           1          thou THAT art NOW the WORLD'S fresh OR na MENT     -+-+-+-+-+  -+-+-+++--   2        11                0.0
#            10       And only herald to the gaudy spring,               12           1          and ON ly HE rald TO the GAU dy SPRING             -+-+-+-+-+  -+-+---+-+   2        11                0.0
#            11       Within thine own bud buriest thy content,          13           1          wit HIN thine OWN bud BU ri EST thy CON tent       -+-+-+-+-+- -+-+++---+-  2        12                0.0
#            12       And, tender churl, mak'st waste in niggarding.     14           1          and TEN der CHURL mak'st WASTE in NIG garding      -+-+-+-+-   -+-+++-+-    2        13                0.0
#            13       Pity the world, or else this glutton be,           17           1          PI ty.the WORLD or ELSE this GLUT ton BE           +--+-+-+-+  +--+-+-+-+   3        16                0.0
#            14       To eat the world's due, by the grave and thee.     19           1          to EAT the WORLD'S.DUE by.the GRAVE and.thee       -+-++--+--  -+-++--+--   3        18                0.0
#
#                                                                                                                                                                                                   *w_stress  \
# stanza_num line_num line_txt                                           linepart_num parse_rank parse_txt                                          parse_meter parse_stress sent_num sentpart_num
# 1          1        From fairest creatures we desire increase,         1            1          from FAI rest CREA tures WE de SIRE in CREASE      -+-+-+-+-+  -+-+---+-+   1        1                   0.0
#            2        That thereby beauty's rose might never die,        2            1          that THE reby BEA uty's ROSE might NE ver DIE      -+-+-+-+-+  -+++-+-+-+   1        2                   1.0
#            3        But as the riper should by time decease,           3            1          but AS the RIPER should.by TIME de CEASE           -+-+--+-+   ---+--+-+    1        3                   0.0
#            4        His tender heir might bear his memory;             4            1          his TEN der HEIR might BEAR his ME mo RY           -+-+-+-+-+  -+-+-+-+--   1        4                   0.0
#            5        But thou, contracted to thine own bright eyes,     5            1          but.thou CON trac TED to.thine OWN bright EYES     --+-+--+-+  --+----+++   1        5                   1.0
#            6        Feed'st thy light's flame with self-substantial... 7            1          FEED'ST thy LIGHT'S.FLAME with SELF subs TAN ti... +-++-+-+-+- +-++-+-+-+-  1        7                   0.0
#            7        Making a famine where abundance lies,              8            1          MA king.a FA mine WHERE a BUN dance LIES           +--+-+-+-+  +--+-+-+-+   1        8                   0.0
#            8        Thyself thy foe, to thy sweet self too cruel.      9            1          thy SELF thy FOE to.thy SWEET self TOO cruel       -+-+--+-+-  -+-+--++++   1        9                   2.0
#            9        Thou that art now the world's fresh ornament       11           1          thou THAT art NOW the WORLD'S fresh OR na MENT     -+-+-+-+-+  -+-+-+++--   2        11                  1.0
#            10       And only herald to the gaudy spring,               12           1          and ON ly HE rald TO the GAU dy SPRING             -+-+-+-+-+  -+-+---+-+   2        11                  0.0
#            11       Within thine own bud buriest thy content,          13           1          wit HIN thine OWN bud BU ri EST thy CON tent       -+-+-+-+-+- -+-+++---+-  2        12                  1.0
#            12       And, tender churl, mak'st waste in niggarding.     14           1          and TEN der CHURL mak'st WASTE in NIG garding      -+-+-+-+-   -+-+++-+-    2        13                  1.0
#            13       Pity the world, or else this glutton be,           17           1          PI ty.the WORLD or ELSE this GLUT ton BE           +--+-+-+-+  +--+-+-+-+   3        16                  0.0
#            14       To eat the world's due, by the grave and thee.     19           1          to EAT the WORLD'S.DUE by.the GRAVE and.thee       -+-++--+--  -+-++--+--   3        18                  0.0
#
#                                                                                                                                                                                                   *s_unstress  \
# stanza_num line_num line_txt                                           linepart_num parse_rank parse_txt                                          parse_meter parse_stress sent_num sentpart_num
# 1          1        From fairest creatures we desire increase,         1            1          from FAI rest CREA tures WE de SIRE in CREASE      -+-+-+-+-+  -+-+---+-+   1        1                     1.0
#            2        That thereby beauty's rose might never die,        2            1          that THE reby BEA uty's ROSE might NE ver DIE      -+-+-+-+-+  -+++-+-+-+   1        2                     0.0
#            3        But as the riper should by time decease,           3            1          but AS the RIPER should.by TIME de CEASE           -+-+--+-+   ---+--+-+    1        3                     1.0
#            4        His tender heir might bear his memory;             4            1          his TEN der HEIR might BEAR his ME mo RY           -+-+-+-+-+  -+-+-+-+--   1        4                     1.0
#            5        But thou, contracted to thine own bright eyes,     5            1          but.thou CON trac TED to.thine OWN bright EYES     --+-+--+-+  --+----+++   1        5                     1.0
#            6        Feed'st thy light's flame with self-substantial... 7            1          FEED'ST thy LIGHT'S.FLAME with SELF subs TAN ti... +-++-+-+-+- +-++-+-+-+-  1        7                     0.0
#            7        Making a famine where abundance lies,              8            1          MA king.a FA mine WHERE a BUN dance LIES           +--+-+-+-+  +--+-+-+-+   1        8                     0.0
#            8        Thyself thy foe, to thy sweet self too cruel.      9            1          thy SELF thy FOE to.thy SWEET self TOO cruel       -+-+--+-+-  -+-+--++++   1        9                     0.0
#            9        Thou that art now the world's fresh ornament       11           1          thou THAT art NOW the WORLD'S fresh OR na MENT     -+-+-+-+-+  -+-+-+++--   2        11                    1.0
#            10       And only herald to the gaudy spring,               12           1          and ON ly HE rald TO the GAU dy SPRING             -+-+-+-+-+  -+-+---+-+   2        11                    1.0
#            11       Within thine own bud buriest thy content,          13           1          wit HIN thine OWN bud BU ri EST thy CON tent       -+-+-+-+-+- -+-+++---+-  2        12                    1.0
#            12       And, tender churl, mak'st waste in niggarding.     14           1          and TEN der CHURL mak'st WASTE in NIG garding      -+-+-+-+-   -+-+++-+-    2        13                    0.0
#            13       Pity the world, or else this glutton be,           17           1          PI ty.the WORLD or ELSE this GLUT ton BE           +--+-+-+-+  +--+-+-+-+   3        16                    0.0
#            14       To eat the world's due, by the grave and thee.     19           1          to EAT the WORLD'S.DUE by.the GRAVE and.thee       -+-++--+--  -+-++--+--   3        18                    0.0
#
#                                                                                                                                                                                                   *unres_across  \
# stanza_num line_num line_txt                                           linepart_num parse_rank parse_txt                                          parse_meter parse_stress sent_num sentpart_num
# 1          1        From fairest creatures we desire increase,         1            1          from FAI rest CREA tures WE de SIRE in CREASE      -+-+-+-+-+  -+-+---+-+   1        1                       0.0
#            2        That thereby beauty's rose might never die,        2            1          that THE reby BEA uty's ROSE might NE ver DIE      -+-+-+-+-+  -+++-+-+-+   1        2                       0.0
#            3        But as the riper should by time decease,           3            1          but AS the RIPER should.by TIME de CEASE           -+-+--+-+   ---+--+-+    1        3                       0.0
#            4        His tender heir might bear his memory;             4            1          his TEN der HEIR might BEAR his ME mo RY           -+-+-+-+-+  -+-+-+-+--   1        4                       0.0
#            5        But thou, contracted to thine own bright eyes,     5            1          but.thou CON trac TED to.thine OWN bright EYES     --+-+--+-+  --+----+++   1        5                       0.0
#            6        Feed'st thy light's flame with self-substantial... 7            1          FEED'ST thy LIGHT'S.FLAME with SELF subs TAN ti... +-++-+-+-+- +-++-+-+-+-  1        7                       1.0
#            7        Making a famine where abundance lies,              8            1          MA king.a FA mine WHERE a BUN dance LIES           +--+-+-+-+  +--+-+-+-+   1        8                       1.0
#            8        Thyself thy foe, to thy sweet self too cruel.      9            1          thy SELF thy FOE to.thy SWEET self TOO cruel       -+-+--+-+-  -+-+--++++   1        9                       0.0
#            9        Thou that art now the world's fresh ornament       11           1          thou THAT art NOW the WORLD'S fresh OR na MENT     -+-+-+-+-+  -+-+-+++--   2        11                      0.0
#            10       And only herald to the gaudy spring,               12           1          and ON ly HE rald TO the GAU dy SPRING             -+-+-+-+-+  -+-+---+-+   2        11                      0.0
#            11       Within thine own bud buriest thy content,          13           1          wit HIN thine OWN bud BU ri EST thy CON tent       -+-+-+-+-+- -+-+++---+-  2        12                      0.0
#            12       And, tender churl, mak'st waste in niggarding.     14           1          and TEN der CHURL mak'st WASTE in NIG garding      -+-+-+-+-   -+-+++-+-    2        13                      0.0
#            13       Pity the world, or else this glutton be,           17           1          PI ty.the WORLD or ELSE this GLUT ton BE           +--+-+-+-+  +--+-+-+-+   3        16                      1.0
#            14       To eat the world's due, by the grave and thee.     19           1          to EAT the WORLD'S.DUE by.the GRAVE and.thee       -+-++--+--  -+-++--+--   3        18                      1.0
#
#                                                                                                                                                                                                   ...  \
# stanza_num line_num line_txt                                           linepart_num parse_rank parse_txt                                          parse_meter parse_stress sent_num sentpart_num  ...
# 1          1        From fairest creatures we desire increase,         1            1          from FAI rest CREA tures WE de SIRE in CREASE      -+-+-+-+-+  -+-+---+-+   1        1             ...
#            2        That thereby beauty's rose might never die,        2            1          that THE reby BEA uty's ROSE might NE ver DIE      -+-+-+-+-+  -+++-+-+-+   1        2             ...
#            3        But as the riper should by time decease,           3            1          but AS the RIPER should.by TIME de CEASE           -+-+--+-+   ---+--+-+    1        3             ...
#            4        His tender heir might bear his memory;             4            1          his TEN der HEIR might BEAR his ME mo RY           -+-+-+-+-+  -+-+-+-+--   1        4             ...
#            5        But thou, contracted to thine own bright eyes,     5            1          but.thou CON trac TED to.thine OWN bright EYES     --+-+--+-+  --+----+++   1        5             ...
#            6        Feed'st thy light's flame with self-substantial... 7            1          FEED'ST thy LIGHT'S.FLAME with SELF subs TAN ti... +-++-+-+-+- +-++-+-+-+-  1        7             ...
#            7        Making a famine where abundance lies,              8            1          MA king.a FA mine WHERE a BUN dance LIES           +--+-+-+-+  +--+-+-+-+   1        8             ...
#            8        Thyself thy foe, to thy sweet self too cruel.      9            1          thy SELF thy FOE to.thy SWEET self TOO cruel       -+-+--+-+-  -+-+--++++   1        9             ...
#            9        Thou that art now the world's fresh ornament       11           1          thou THAT art NOW the WORLD'S fresh OR na MENT     -+-+-+-+-+  -+-+-+++--   2        11            ...
#            10       And only herald to the gaudy spring,               12           1          and ON ly HE rald TO the GAU dy SPRING             -+-+-+-+-+  -+-+---+-+   2        11            ...
#            11       Within thine own bud buriest thy content,          13           1          wit HIN thine OWN bud BU ri EST thy CON tent       -+-+-+-+-+- -+-+++---+-  2        12            ...
#            12       And, tender churl, mak'st waste in niggarding.     14           1          and TEN der CHURL mak'st WASTE in NIG garding      -+-+-+-+-   -+-+++-+-    2        13            ...
#            13       Pity the world, or else this glutton be,           17           1          PI ty.the WORLD or ELSE this GLUT ton BE           +--+-+-+-+  +--+-+-+-+   3        16            ...
#            14       To eat the world's due, by the grave and thee.     19           1          to EAT the WORLD'S.DUE by.the GRAVE and.thee       -+-++--+--  -+-++--+--   3        18            ...
#
#                                                                                                                                                                                                   *total_sylls  \
# stanza_num line_num line_txt                                           linepart_num parse_rank parse_txt                                          parse_meter parse_stress sent_num sentpart_num
# 1          1        From fairest creatures we desire increase,         1            1          from FAI rest CREA tures WE de SIRE in CREASE      -+-+-+-+-+  -+-+---+-+   1        1                        1
#            2        That thereby beauty's rose might never die,        2            1          that THE reby BEA uty's ROSE might NE ver DIE      -+-+-+-+-+  -+++-+-+-+   1        2                        1
#            3        But as the riper should by time decease,           3            1          but AS the RIPER should.by TIME de CEASE           -+-+--+-+   ---+--+-+    1        3                        1
#            4        His tender heir might bear his memory;             4            1          his TEN der HEIR might BEAR his ME mo RY           -+-+-+-+-+  -+-+-+-+--   1        4                        1
#            5        But thou, contracted to thine own bright eyes,     5            1          but.thou CON trac TED to.thine OWN bright EYES     --+-+--+-+  --+----+++   1        5                        2
#            6        Feed'st thy light's flame with self-substantial... 7            1          FEED'ST thy LIGHT'S.FLAME with SELF subs TAN ti... +-++-+-+-+- +-++-+-+-+-  1        7                        1
#            7        Making a famine where abundance lies,              8            1          MA king.a FA mine WHERE a BUN dance LIES           +--+-+-+-+  +--+-+-+-+   1        8                        1
#            8        Thyself thy foe, to thy sweet self too cruel.      9            1          thy SELF thy FOE to.thy SWEET self TOO cruel       -+-+--+-+-  -+-+--++++   1        9                        2
#            9        Thou that art now the world's fresh ornament       11           1          thou THAT art NOW the WORLD'S fresh OR na MENT     -+-+-+-+-+  -+-+-+++--   2        11                       2
#            10       And only herald to the gaudy spring,               12           1          and ON ly HE rald TO the GAU dy SPRING             -+-+-+-+-+  -+-+---+-+   2        11                       1
#            11       Within thine own bud buriest thy content,          13           1          wit HIN thine OWN bud BU ri EST thy CON tent       -+-+-+-+-+- -+-+++---+-  2        12                       2
#            12       And, tender churl, mak'st waste in niggarding.     14           1          and TEN der CHURL mak'st WASTE in NIG garding      -+-+-+-+-   -+-+++-+-    2        13                       1
#            13       Pity the world, or else this glutton be,           17           1          PI ty.the WORLD or ELSE this GLUT ton BE           +--+-+-+-+  +--+-+-+-+   3        16                       1
#            14       To eat the world's due, by the grave and thee.     19           1          to EAT the WORLD'S.DUE by.the GRAVE and.thee       -+-++--+--  -+-++--+--   3        18                       1
#
#                                                                                                                                                                                                   *total  \
# stanza_num line_num line_txt                                           linepart_num parse_rank parse_txt                                          parse_meter parse_stress sent_num sentpart_num
# 1          1        From fairest creatures we desire increase,         1            1          from FAI rest CREA tures WE de SIRE in CREASE      -+-+-+-+-+  -+-+---+-+   1        1                  1
#            2        That thereby beauty's rose might never die,        2            1          that THE reby BEA uty's ROSE might NE ver DIE      -+-+-+-+-+  -+++-+-+-+   1        2                  1
#            3        But as the riper should by time decease,           3            1          but AS the RIPER should.by TIME de CEASE           -+-+--+-+   ---+--+-+    1        3                  1
#            4        His tender heir might bear his memory;             4            1          his TEN der HEIR might BEAR his ME mo RY           -+-+-+-+-+  -+-+-+-+--   1        4                  1
#            5        But thou, contracted to thine own bright eyes,     5            1          but.thou CON trac TED to.thine OWN bright EYES     --+-+--+-+  --+----+++   1        5                  2
#            6        Feed'st thy light's flame with self-substantial... 7            1          FEED'ST thy LIGHT'S.FLAME with SELF subs TAN ti... +-++-+-+-+- +-++-+-+-+-  1        7                  1
#            7        Making a famine where abundance lies,              8            1          MA king.a FA mine WHERE a BUN dance LIES           +--+-+-+-+  +--+-+-+-+   1        8                  1
#            8        Thyself thy foe, to thy sweet self too cruel.      9            1          thy SELF thy FOE to.thy SWEET self TOO cruel       -+-+--+-+-  -+-+--++++   1        9                  2
#            9        Thou that art now the world's fresh ornament       11           1          thou THAT art NOW the WORLD'S fresh OR na MENT     -+-+-+-+-+  -+-+-+++--   2        11                 2
#            10       And only herald to the gaudy spring,               12           1          and ON ly HE rald TO the GAU dy SPRING             -+-+-+-+-+  -+-+---+-+   2        11                 1
#            11       Within thine own bud buriest thy content,          13           1          wit HIN thine OWN bud BU ri EST thy CON tent       -+-+-+-+-+- -+-+++---+-  2        12                 2
#            12       And, tender churl, mak'st waste in niggarding.     14           1          and TEN der CHURL mak'st WASTE in NIG garding      -+-+-+-+-   -+-+++-+-    2        13                 1
#            13       Pity the world, or else this glutton be,           17           1          PI ty.the WORLD or ELSE this GLUT ton BE           +--+-+-+-+  +--+-+-+-+   3        16                 1
#            14       To eat the world's due, by the grave and thee.     19           1          to EAT the WORLD'S.DUE by.the GRAVE and.thee       -+-++--+--  -+-++--+--   3        18                 1
#
#                                                                                                                                                                                                   *w_peak_norm  \
# stanza_num line_num line_txt                                           linepart_num parse_rank parse_txt                                          parse_meter parse_stress sent_num sentpart_num
# 1          1        From fairest creatures we desire increase,         1            1          from FAI rest CREA tures WE de SIRE in CREASE      -+-+-+-+-+  -+-+---+-+   1        1                      0.0
#            2        That thereby beauty's rose might never die,        2            1          that THE reby BEA uty's ROSE might NE ver DIE      -+-+-+-+-+  -+++-+-+-+   1        2                      0.0
#            3        But as the riper should by time decease,           3            1          but AS the RIPER should.by TIME de CEASE           -+-+--+-+   ---+--+-+    1        3                      0.0
#            4        His tender heir might bear his memory;             4            1          his TEN der HEIR might BEAR his ME mo RY           -+-+-+-+-+  -+-+-+-+--   1        4                      0.0
#            5        But thou, contracted to thine own bright eyes,     5            1          but.thou CON trac TED to.thine OWN bright EYES     --+-+--+-+  --+----+++   1        5                      0.0
#            6        Feed'st thy light's flame with self-substantial... 7            1          FEED'ST thy LIGHT'S.FLAME with SELF subs TAN ti... +-++-+-+-+- +-++-+-+-+-  1        7                      0.0
#            7        Making a famine where abundance lies,              8            1          MA king.a FA mine WHERE a BUN dance LIES           +--+-+-+-+  +--+-+-+-+   1        8                      0.0
#            8        Thyself thy foe, to thy sweet self too cruel.      9            1          thy SELF thy FOE to.thy SWEET self TOO cruel       -+-+--+-+-  -+-+--++++   1        9                      0.0
#            9        Thou that art now the world's fresh ornament       11           1          thou THAT art NOW the WORLD'S fresh OR na MENT     -+-+-+-+-+  -+-+-+++--   2        11                     0.0
#            10       And only herald to the gaudy spring,               12           1          and ON ly HE rald TO the GAU dy SPRING             -+-+-+-+-+  -+-+---+-+   2        11                     0.0
#            11       Within thine own bud buriest thy content,          13           1          wit HIN thine OWN bud BU ri EST thy CON tent       -+-+-+-+-+- -+-+++---+-  2        12                     0.0
#            12       And, tender churl, mak'st waste in niggarding.     14           1          and TEN der CHURL mak'st WASTE in NIG garding      -+-+-+-+-   -+-+++-+-    2        13                     0.0
#            13       Pity the world, or else this glutton be,           17           1          PI ty.the WORLD or ELSE this GLUT ton BE           +--+-+-+-+  +--+-+-+-+   3        16                     0.0
#            14       To eat the world's due, by the grave and thee.     19           1          to EAT the WORLD'S.DUE by.the GRAVE and.thee       -+-++--+--  -+-++--+--   3        18                     0.0
#
# ...
#            5        But thou, contracted to thine own bright eyes,     5            1          but.thou CON trac TED to.thine OWN bright EYES     --+-+--+-+  --+----+++   1        5                       0.000000
#            6        Feed'st thy light's flame with self-substantial... 7            1          FEED'ST thy LIGHT'S.FLAME with SELF subs TAN ti... +-++-+-+-+- +-++-+-+-+-  1        7                       0.090909
#            7        Making a famine where abundance lies,              8            1          MA king.a FA mine WHERE a BUN dance LIES           +--+-+-+-+  +--+-+-+-+   1        8                       0.100000
#            8        Thyself thy foe, to thy sweet self too cruel.      9            1          thy SELF thy FOE to.thy SWEET self TOO cruel       -+-+--+-+-  -+-+--++++   1        9                       0.000000
#            9        Thou that art now the world's fresh ornament       11           1          thou THAT art NOW the WORLD'S fresh OR na MENT     -+-+-+-+-+  -+-+-+++--   2        11                      0.000000
#            10       And only herald to the gaudy spring,               12           1          and ON ly HE rald TO the GAU dy SPRING             -+-+-+-+-+  -+-+---+-+   2        11                      0.000000
#            11       Within thine own bud buriest thy content,          13           1          wit HIN thine OWN bud BU ri EST thy CON tent       -+-+-+-+-+- -+-+++---+-  2        12                      0.000000
#            12       And, tender churl, mak'st waste in niggarding.     14           1          and TEN der CHURL mak'st WASTE in NIG garding      -+-+-+-+-   -+-+++-+-    2        13                      0.000000
#            13       Pity the world, or else this glutton be,           17           1          PI ty.the WORLD or ELSE this GLUT ton BE           +--+-+-+-+  +--+-+-+-+   3        16                      0.100000
#            14       To eat the world's due, by the grave and thee.     19           1          to EAT the WORLD'S.DUE by.the GRAVE and.thee       -+-++--+--  -+-++--+--   3        18                      0.100000
#
#                                                                                                                                                                                                   *unres_within_norm  \
# stanza_num line_num line_txt                                           linepart_num parse_rank parse_txt                                          parse_meter parse_stress sent_num sentpart_num
# 1          1        From fairest creatures we desire increase,         1            1          from FAI rest CREA tures WE de SIRE in CREASE      -+-+-+-+-+  -+-+---+-+   1        1                            0.0
#            2        That thereby beauty's rose might never die,        2            1          that THE reby BEA uty's ROSE might NE ver DIE      -+-+-+-+-+  -+++-+-+-+   1        2                            0.0
#            3        But as the riper should by time decease,           3            1          but AS the RIPER should.by TIME de CEASE           -+-+--+-+   ---+--+-+    1        3                            0.0
#            4        His tender heir might bear his memory;             4            1          his TEN der HEIR might BEAR his ME mo RY           -+-+-+-+-+  -+-+-+-+--   1        4                            0.0
#            5        But thou, contracted to thine own bright eyes,     5            1          but.thou CON trac TED to.thine OWN bright EYES     --+-+--+-+  --+----+++   1        5                            0.0
#            6        Feed'st thy light's flame with self-substantial... 7            1          FEED'ST thy LIGHT'S.FLAME with SELF subs TAN ti... +-++-+-+-+- +-++-+-+-+-  1        7                            0.0
#            7        Making a famine where abundance lies,              8            1          MA king.a FA mine WHERE a BUN dance LIES           +--+-+-+-+  +--+-+-+-+   1        8                            0.0
#            8        Thyself thy foe, to thy sweet self too cruel.      9            1          thy SELF thy FOE to.thy SWEET self TOO cruel       -+-+--+-+-  -+-+--++++   1        9                            0.0
#            9        Thou that art now the world's fresh ornament       11           1          thou THAT art NOW the WORLD'S fresh OR na MENT     -+-+-+-+-+  -+-+-+++--   2        11                           0.0
#            10       And only herald to the gaudy spring,               12           1          and ON ly HE rald TO the GAU dy SPRING             -+-+-+-+-+  -+-+---+-+   2        11                           0.0
#            11       Within thine own bud buriest thy content,          13           1          wit HIN thine OWN bud BU ri EST thy CON tent       -+-+-+-+-+- -+-+++---+-  2        12                           0.0
#            12       And, tender churl, mak'st waste in niggarding.     14           1          and TEN der CHURL mak'st WASTE in NIG garding      -+-+-+-+-   -+-+++-+-    2        13                           0.0
#            13       Pity the world, or else this glutton be,           17           1          PI ty.the WORLD or ELSE this GLUT ton BE           +--+-+-+-+  +--+-+-+-+   3        16                           0.0
#            14       To eat the world's due, by the grave and thee.     19           1          to EAT the WORLD'S.DUE by.the GRAVE and.thee       -+-++--+--  -+-++--+--   3        18                           0.0
#
#                                                                                                                                                                                                   *foot_size_norm  \
# stanza_num line_num line_txt                                           linepart_num parse_rank parse_txt                                          parse_meter parse_stress sent_num sentpart_num
# 1          1        From fairest creatures we desire increase,         1            1          from FAI rest CREA tures WE de SIRE in CREASE      -+-+-+-+-+  -+-+---+-+   1        1                         0.0
#            2        That thereby beauty's rose might never die,        2            1          that THE reby BEA uty's ROSE might NE ver DIE      -+-+-+-+-+  -+++-+-+-+   1        2                         0.0
#            3        But as the riper should by time decease,           3            1          but AS the RIPER should.by TIME de CEASE           -+-+--+-+   ---+--+-+    1        3                         0.0
#            4        His tender heir might bear his memory;             4            1          his TEN der HEIR might BEAR his ME mo RY           -+-+-+-+-+  -+-+-+-+--   1        4                         0.0
#            5        But thou, contracted to thine own bright eyes,     5            1          but.thou CON trac TED to.thine OWN bright EYES     --+-+--+-+  --+----+++   1        5                         0.0
#            6        Feed'st thy light's flame with self-substantial... 7            1          FEED'ST thy LIGHT'S.FLAME with SELF subs TAN ti... +-++-+-+-+- +-++-+-+-+-  1        7                         0.0
#            7        Making a famine where abundance lies,              8            1          MA king.a FA mine WHERE a BUN dance LIES           +--+-+-+-+  +--+-+-+-+   1        8                         0.0
#            8        Thyself thy foe, to thy sweet self too cruel.      9            1          thy SELF thy FOE to.thy SWEET self TOO cruel       -+-+--+-+-  -+-+--++++   1        9                         0.0
#            9        Thou that art now the world's fresh ornament       11           1          thou THAT art NOW the WORLD'S fresh OR na MENT     -+-+-+-+-+  -+-+-+++--   2        11                        0.0
#            10       And only herald to the gaudy spring,               12           1          and ON ly HE rald TO the GAU dy SPRING             -+-+-+-+-+  -+-+---+-+   2        11                        0.0
#            11       Within thine own bud buriest thy content,          13           1          wit HIN thine OWN bud BU ri EST thy CON tent       -+-+-+-+-+- -+-+++---+-  2        12                        0.0
#            12       And, tender churl, mak'st waste in niggarding.     14           1          and TEN der CHURL mak'st WASTE in NIG garding      -+-+-+-+-   -+-+++-+-    2        13                        0.0
#            13       Pity the world, or else this glutton be,           17           1          PI ty.the WORLD or ELSE this GLUT ton BE           +--+-+-+-+  +--+-+-+-+   3        16                        0.0
#            14       To eat the world's due, by the grave and thee.     19           1          to EAT the WORLD'S.DUE by.the GRAVE and.thee       -+-++--+--  -+-++--+--   3        18                        0.0
#
#                                                                                                                                                                                                   *total_sylls_norm  \
# stanza_num line_num line_txt                                           linepart_num parse_rank parse_txt                                          parse_meter parse_stress sent_num sentpart_num
# 1          1        From fairest creatures we desire increase,         1            1          from FAI rest CREA tures WE de SIRE in CREASE      -+-+-+-+-+  -+-+---+-+   1        1                      0.100000
#            2        That thereby beauty's rose might never die,        2            1          that THE reby BEA uty's ROSE might NE ver DIE      -+-+-+-+-+  -+++-+-+-+   1        2                      0.100000
#            3        But as the riper should by time decease,           3            1          but AS the RIPER should.by TIME de CEASE           -+-+--+-+   ---+--+-+    1        3                      0.111111
#            4        His tender heir might bear his memory;             4            1          his TEN der HEIR might BEAR his ME mo RY           -+-+-+-+-+  -+-+-+-+--   1        4                      0.100000
#            5        But thou, contracted to thine own bright eyes,     5            1          but.thou CON trac TED to.thine OWN bright EYES     --+-+--+-+  --+----+++   1        5                      0.200000
#            6        Feed'st thy light's flame with self-substantial... 7            1          FEED'ST thy LIGHT'S.FLAME with SELF subs TAN ti... +-++-+-+-+- +-++-+-+-+-  1        7                      0.090909
#            7        Making a famine where abundance lies,              8            1          MA king.a FA mine WHERE a BUN dance LIES           +--+-+-+-+  +--+-+-+-+   1        8                      0.100000
#            8        Thyself thy foe, to thy sweet self too cruel.      9            1          thy SELF thy FOE to.thy SWEET self TOO cruel       -+-+--+-+-  -+-+--++++   1        9                      0.200000
#            9        Thou that art now the world's fresh ornament       11           1          thou THAT art NOW the WORLD'S fresh OR na MENT     -+-+-+-+-+  -+-+-+++--   2        11                     0.200000
#            10       And only herald to the gaudy spring,               12           1          and ON ly HE rald TO the GAU dy SPRING             -+-+-+-+-+  -+-+---+-+   2        11                     0.100000
#            11       Within thine own bud buriest thy content,          13           1          wit HIN thine OWN bud BU ri EST thy CON tent       -+-+-+-+-+- -+-+++---+-  2        12                     0.181818
#            12       And, tender churl, mak'st waste in niggarding.     14           1          and TEN der CHURL mak'st WASTE in NIG garding      -+-+-+-+-   -+-+++-+-    2        13                     0.111111
#            13       Pity the world, or else this glutton be,           17           1          PI ty.the WORLD or ELSE this GLUT ton BE           +--+-+-+-+  +--+-+-+-+   3        16                     0.100000
#            14       To eat the world's due, by the grave and thee.     19           1          to EAT the WORLD'S.DUE by.the GRAVE and.thee       -+-++--+--  -+-++--+--   3        18                     0.100000
#
#                                                                                                                                                                                                   *total_norm
# stanza_num line_num line_txt                                           linepart_num parse_rank parse_txt                                          parse_meter parse_stress sent_num sentpart_num
# 1          1        From fairest creatures we desire increase,         1            1          from FAI rest CREA tures WE de SIRE in CREASE      -+-+-+-+-+  -+-+---+-+   1        1                0.100000
#            2        That thereby beauty's rose might never die,        2            1          that THE reby BEA uty's ROSE might NE ver DIE      -+-+-+-+-+  -+++-+-+-+   1        2                0.100000
#            3        But as the riper should by time decease,           3            1          but AS the RIPER should.by TIME de CEASE           -+-+--+-+   ---+--+-+    1        3                0.111111
#            4        His tender heir might bear his memory;             4            1          his TEN der HEIR might BEAR his ME mo RY           -+-+-+-+-+  -+-+-+-+--   1        4                0.100000
#            5        But thou, contracted to thine own bright eyes,     5            1          but.thou CON trac TED to.thine OWN bright EYES     --+-+--+-+  --+----+++   1        5                0.200000
#            6        Feed'st thy light's flame with self-substantial... 7            1          FEED'ST thy LIGHT'S.FLAME with SELF subs TAN ti... +-++-+-+-+- +-++-+-+-+-  1        7                0.090909
#            7        Making a famine where abundance lies,              8            1          MA king.a FA mine WHERE a BUN dance LIES           +--+-+-+-+  +--+-+-+-+   1        8                0.100000
#            8        Thyself thy foe, to thy sweet self too cruel.      9            1          thy SELF thy FOE to.thy SWEET self TOO cruel       -+-+--+-+-  -+-+--++++   1        9                0.200000
#            9        Thou that art now the world's fresh ornament       11           1          thou THAT art NOW the WORLD'S fresh OR na MENT     -+-+-+-+-+  -+-+-+++--   2        11               0.200000
#            10       And only herald to the gaudy spring,               12           1          and ON ly HE rald TO the GAU dy SPRING             -+-+-+-+-+  -+-+---+-+   2        11               0.100000
#            11       Within thine own bud buriest thy content,          13           1          wit HIN thine OWN bud BU ri EST thy CON tent       -+-+-+-+-+- -+-+++---+-  2        12               0.181818
#            12       And, tender churl, mak'st waste in niggarding.     14           1          and TEN der CHURL mak'st WASTE in NIG garding      -+-+-+-+-   -+-+++-+-    2        13               0.111111
#            13       Pity the world, or else this glutton be,           17           1          PI ty.the WORLD or ELSE this GLUT ton BE           +--+-+-+-+  +--+-+-+-+   3        16               0.100000
#            14       To eat the world's due, by the grave and thee.     19           1          to EAT the WORLD'S.DUE by.the GRAVE and.thee       -+-++--+--  -+-++--+--   3        18               0.100000
#
# [14 rows x 22 columns]

# %%
documentation(get_rhythm_for_txt)

rhythm_data = get_rhythm_for_txt(txt)
assert rhythm_data == postprocess_parses_data(parses_df)
rhythm_data
# Out:
# ##### `get_rhythm_for_txt`
#
# ```md
# Get rhythm measurements for a single poem text.
#
#     Convenience function that retrieves processed rhythm measurements for a text,
#     equivalent to calling get_parses_for_txt with postprocess=True.
#
#     Parameters
#     ----------
#     txt : str
#         The poem text to analyze.
#     **kwargs
#         Additional keyword arguments passed to get_parses_for_txt.
#
#     Returns
#     -------
#     dict
#         Dictionary of rhythm measurements, or empty dict if parsing fails.
#
#     Calls
#     -----
#     - get_parses_for_txt(txt, postprocess=True, **kwargs)
#
# ```
# ----
# {'is_iambic_pentameter': 0.35714285714285715,
#  'is_unambigously_iambic_pentameter': 0.14285714285714285,
#  'syll01_stress': 0.21428571428571427,
#  'syll02_stress': 0.6428571428571429,
#  'syll03_stress': 0.21428571428571427,
#  'syll04_stress': 0.9285714285714286,
#  'syll05_stress': 0.21428571428571427,
#  'syll06_stress': 0.5714285714285714,
#  'syll07_stress': 0.21428571428571427,
#  'syll08_stress': 0.8571428571428571,
#  'syll09_stress': 0.21428571428571427,
#  'syll10_stress': 0.75,
#  'forth_syllable_stressed': 0.9285714285714286,
#  'perc_ww_in_meter': 0.06153846153846154}

# %%
documentation(get_rhythm_for_shakespeare_sonnets)
df_shak_rhythm = get_rhythm_for_shakespeare_sonnets()
df_shak_rhythm
# Out:
# ##### `get_rhythm_for_shakespeare_sonnets`
#
# ```md
# Load and analyze rhythm in Shakespeare's sonnets.
#
#     Reads the complete text of Shakespeare's sonnets, splits into individual poems,
#     and computes rhythm measurements for each sonnet.
#
#     Parameters
#     ----------
#     force : bool, default=False
#         If True, re-parse sonnets even if cached data exists.
#
#     Returns
#     -------
#     pd.DataFrame
#         DataFrame with rhythm measurements for each of the 154 sonnets,
#         indexed by sonnet ID (e.g., 'shakespeare_sonnet_001').
#
#     Calls
#     -----
#     - get_id_hash(s) [for each sonnet text]
#     - get_rhythm_for_txt(txt, force=force) [for each sonnet]
#
# ```
# ----
# * Getting rhythm for shakespeare sonnets: 100%|██████████| 154/154 [00:00<00:00, 229.19it/s]
#                         id_hash                                                txt  is_iambic_pentameter  is_unambigously_iambic_pentameter  syll01_stress  syll02_stress  syll03_stress  \
# id
# shakespeare_sonnet_001   707167  FROM fairest creatures we desire increase,\nTh...              0.357143                           0.142857       0.214286       0.642857       0.214286
# shakespeare_sonnet_002   911590  When forty winters shall beseige thy brow,\nAn...              0.714286                           0.428571       0.071429       0.714286       0.214286
# shakespeare_sonnet_003   369626  Look in thy glass, and tell the face thou view...              0.357143                           0.071429       0.285714       0.642857       0.071429
# shakespeare_sonnet_004   891098  Unthrifty loveliness, why dost thou spend\nUpo...              0.500000                           0.214286       0.285714       0.571429       0.214286
# shakespeare_sonnet_005   644683  Those hours, that with gentle work did frame\n...              0.500000                           0.285714       0.357143       0.642857       0.071429
# ...                         ...                                                ...                   ...                                ...            ...            ...            ...
# shakespeare_sonnet_150   876499  O, from what power hast thou this powerful mig...              0.642857                           0.142857       0.000000       0.642857       0.000000
# shakespeare_sonnet_151   169495  Love is too young to know what conscience is;\...              0.428571                           0.142857       0.214286       0.571429       0.214286
# shakespeare_sonnet_152   962496  In loving thee thou know'st I am forsworn,\nBu...              0.357143                           0.214286       0.071429       0.571429       0.071429
# shakespeare_sonnet_153   775847  Cupid laid by his brand, and fell asleep:\nA m...              0.571429                           0.285714       0.071429       0.785714       0.428571
# shakespeare_sonnet_154   231306  The little Love-god lying once asleep\nLaid by...              0.500000                           0.142857       0.428571       0.642857       0.071429
#
#                         syll04_stress  syll05_stress  syll06_stress  syll07_stress  syll08_stress  syll09_stress  syll10_stress  forth_syllable_stressed  perc_ww_in_meter
# id
# shakespeare_sonnet_001       0.928571       0.214286       0.500000       0.285714       0.785714       0.285714       0.692308                 0.928571          0.061538
# shakespeare_sonnet_002       0.928571       0.214286       0.714286       0.285714       0.928571       0.071429       0.846154                 0.928571          0.037879
# shakespeare_sonnet_003       0.785714       0.000000       0.785714       0.071429       0.642857       0.214286       0.692308                 0.785714          0.060150
# shakespeare_sonnet_004       0.857143       0.071429       0.785714       0.071429       0.500000       0.142857       0.833333                 0.857143          0.070866
# shakespeare_sonnet_005       0.785714       0.142857       0.785714       0.071429       0.714286       0.285714       0.714286                 0.785714          0.059701
# ...                               ...            ...            ...            ...            ...            ...            ...                      ...               ...
# shakespeare_sonnet_150       0.714286       0.071429       0.785714       0.142857       0.714286       0.214286       0.785714                 0.714286          0.036765
# shakespeare_sonnet_151       0.714286       0.214286       0.785714       0.357143       0.714286       0.142857       0.714286                 0.714286          0.062500
# shakespeare_sonnet_152       0.928571       0.357143       0.857143       0.071429       0.571429       0.357143       0.928571                 0.928571          0.036232
# shakespeare_sonnet_153       0.785714       0.142857       0.785714       0.214286       0.785714       0.230769       1.000000                 0.785714          0.030303
# shakespeare_sonnet_154       0.857143       0.142857       0.571429       0.357143       0.785714       0.214286       0.692308                 0.857143          0.045802
#
# [154 rows x 16 columns]

# %%
documentation(get_rhythm_for_sample)

df_smpl = get_chadwyck_corpus_sampled_by('sonnet_period')
df_smpl_rhythm = get_rhythm_for_sample(df_smpl)
# Out:
# ##### `get_rhythm_for_sample`
#
# ```md
# Extract rhythm measurements for a sample of poems.
#
#     Computes rhythm measurements (meter, stress patterns, etc.) for each poem
#     in the sample, returning a DataFrame with one row per poem.
#
#     Parameters
#     ----------
#     df_smpl : pd.DataFrame
#         DataFrame containing poem texts in a 'txt' column, indexed by poem IDs.
#     stash : HashStash, default=STASH_RHYTHM
#         Cache storage for parsed data.
#     force : bool, default=False
#         If True, re-parse even if cached data exists.
#     gen : bool, default=True
#         If True, generate new parses; if False, only use cached data.
#     verbose : bool, default=DEFAULT_VERBOSE
#         If True, show progress information.
#     **kwargs
#         Additional keyword arguments (unused).
#
#     Returns
#     -------
#     pd.DataFrame
#         DataFrame with rhythm measurements, indexed by poem ID, or empty
#         DataFrame if no valid measurements found.
#
#     Calls
#     -----
#     - _clean_df(df_smpl)
#     - get_rhythm_for_txt(txt, stash=stash, force=force, postprocess=True) [if gen=True]
#     - postprocess_parses_data(stash.get(txt)) [if gen=False]
#
# ```
# ----
# * Getting rhythm for sample: 100%|██████████| 999/999 [00:05<00:00, 175.67it/s]
