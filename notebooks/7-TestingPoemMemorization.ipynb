# %%
# !pip install -r ../../prosodic/requirements.txt
import sys
sys.path.insert(0,'..')
from generative_formalism import *

# %%
df1.columns
# Out:
# Index(['id', 'id_hash', 'period_meta', 'subcorpus', 'author', 'author_dob', 'title', 'year', 'num_lines', 'volume', 'line', 'rhyme', 'genre', 'period', 'txt'], dtype='object')

# %%
df = get_rhyme_for_completed_poems(filter_line_sim=False)
# Out:
# 100%|██████████| 22458/22458 [00:05<00:00, 3986.00it/s]

# %%
df['found'] = df.line_sim > 95

# %%
df_meta = get_chadwyck_corpus(period_by=50)
df_dolma=pd.read_pickle('/Users/ryan/Dropbox/Prof/Data/data.found_dolma.pkl')

# rename poem column to txt column
df_dolma = df_dolma.rename(columns={'poem':'txt'})
df_dolma_meta = df_dolma[['id','txt','count','found']].merge(df_meta, on='id')
df_dolma_meta.to_csv('../data/corpus_found_dolma.csv.gz', index=False)
df_dolma_meta
# Out:
#                                            id                                                txt  count  found  id_hash                             period_meta                subcorpus  \
# 0             c20-american/am20114/Z300221220  Tambourines!\nTambourines!\nTambourines\nTo th...    219   True   999655             1900-1999 Twentieth-Century          American Poetry
# 1                 english/wattsisa/Z400522989  When I survey the wondrous cross\nOn which the...     99   True   515246      1750-1799 Later Eighteenth-Century           English Poetry
# 2             english-ed2/miscell3/Z300440750  Go, lovely Rose!\nTell her, that wastes her ti...     97   True   218382  1550-1900 Miscellanies and Collections           English Poetry
# 3             c20-american/am20114/Z300220672  I must say\nYes, sir,\nTo you all the time.\nY...     60   True   427210             1900-1999 Twentieth-Century          American Poetry
# 4                 english/wattsisa/Z400522722  Come let us join our cheerful songs\n    With ...     31   True   325150      1750-1799 Later Eighteenth-Century           English Poetry
# ...                                       ...                                                ...    ...    ...      ...                                     ...                      ...
# 4630  c20-african-american/da20096/Z200331275  Off go the crows from the roof.\nThe crows can...      0  False   673433             1900-1999 Twentieth-Century  African-American Poetry
# 4631          c20-american/am30242/Z300570450  The trees in clouds of November missed\nStandi...      0  False   154819             1900-1999 Twentieth-Century          American Poetry
# 4632              english/priormat/Z300465735  Haste my Nannette, my lovely maid,\nHaste to t...      0  False   533684      1700-1749 Early Eighteenth-Century           English Poetry
# 4633               american/am0076/Z200145561  Thine eyes shall see the light of distant skie...      0  False   657643        1835-1869 Mid Nineteenth-Century          American Poetry
# 4634              english/rawnsley/Z300472911  The corn was yellow by the Lowland braes,\n   ...      0  False   576295      1870-1899 Later Nineteenth-Century           English Poetry
#
#                                                author author_dob                                              title  year  num_lines                          volume  \
# 0                        Hughes, Langston, 1902-1967.     1902.0                                        Tambourines  1932         16
# 1                             Watts, Isaac, 1674-1748     1674.0  HYMN 7. (L. M.) Crucifixion to the World by th...  1704         20                The Works (1810)
# 2                           Waller, Edmund, 1606-1687     1606.0                            CXV  [Go, lovely Rose!]  1636         20
# 3                        Hughes, Langston, 1902-1967.     1902.0                                             Porter  1932         15
# 4                             Watts, Isaac, 1674-1748     1674.0  HYMN 62. (C. M.) Christ Jesus, the Lamb of God...  1704         20                The Works (1810)
# ...                                               ...        ...                                                ...   ...        ...                             ...
# 4630                           Eady, Cornelius, 1954-     1954.0                             CROWS IN A STRONG WIND  1984         20
# 4631                           Kinnell, Galway, 1927-     1927.0                               EARTH&hyphen;SPARROW  1957         17
# 4632                        Prior, Matthew, 1664-1721     1664.0                                 Nannette.  A Song.  1694         14    Dialogues of the Dead (1907)
# 4633                Bryant, William Cullen, 1794-1878     1794.0        TO COLE, THE PAINTER, DEPARTING FOR EUROPE.  1824         14       The Poetical Works (1903)
# 4634  Rawnsley, H. D. (Hardwicke Drummond), 1851-1920     1851.0                       Lord Justice General Inglis.  1881         14  Valete: Tennyson [etc.] (1893)
#
#                                                   line rhyme   genre     period
# 0                                         Tambourines!                1900-1950
# 1                   On which the prince of glory dy'd,     y   Lyric  1650-1700
# 2                             &indent;Go, lovely Rose!     y          1600-1650
# 3                                           I must say                1900-1950
# 4                &indent;With angels round the throne;     y   Lyric  1650-1700
# ...                                                ...   ...     ...        ...
# 4630                   Off go the crows from the roof.                1950-2000
# 4631              The trees in clouds of November mist                1900-1950
# 4632           Haste to the bower, thy swain has made.     y          1650-1700
# 4633    &indent;A living image of our own bright land,     y  Sonnet  1750-1800
# 4634  &indent;The Highland heather purple on the hill,     y  Sonnet  1850-1900
#
# [4635 rows x 17 columns]

# %%
def get_antoniak_et_al_memorization_data(poetry_eval_repo_dir='../../poetry-eval'):
    data_fldr = os.path.join(poetry_eval_repo_dir, 'data')
    df_antoniak = pd.read_csv(os.path.join(data_fldr, 'poetry-evaluation_public-domain-poems.csv'))
    df_antoniak['id'] = df_antoniak['poem_link'].apply(lambda x: '/'.join(x.split('/')[-2:]))
    df_antoniak = df_antoniak.rename(columns={'poem_text':'txt'})
    df_antoniak = df_antoniak.set_index('id')
    # df_walsh.to_csv('../data/antoniak_et_al.poetry-evaluation_public-domain-poems.csv.gz')

    df_mem=pd.read_csv(os.path.join(data_fldr, 'memorization_results.csv')).drop('Unnamed: 0',axis=1)
    df_mem = df_mem.rename(columns={'poem':'id', 'prediction':'found_closed'})
    df_mem['found_closed'] = df_mem['found_closed'].astype(bool)
    df_mem_antoniak = df_antoniak.merge(df_mem, on='id').set_index('id')
    
    df_mem_antoniak['found_open'] = False
    
    for fn in os.listdir(data_fldr):
        if 'wimbd' in fn:
            fndf=pd.read_csv(os.path.join(data_fldr,fn))
            for poem_id in fndf.poem_id.unique():
                if poem_id in df_mem_antoniak.index:
                    df_mem_antoniak.loc[poem_id, 'found_open'] = True
    
    df_mem_antoniak.to_csv('../data/antoniak_et_al_memorization_results.csv.gz')
    return df_mem_antoniak

# %%
df_antoniak_mem = get_antoniak_et_al_memorization_data()
df_antoniak_mem
# Out:
#                                                                author birth_death_dates                                         poem_title                                                txt  \
# id
# 43926/the-canterbury-tales-general-prologue          Geoffrey Chaucer            ?–1400             The Canterbury Tales: General Prologue  Here bygynneth the Book of the tales of Caunte...
# 144612/where-did-the-handsome-beloved-go            Jalal al-Din Rumi         1207–1273               “Where did the handsome beloved go?”  Where did the handsome beloved go?\nI wonder, ...
# poem/sonnet-131-id-sing-love-such-novel-fashion              Petrarch       1304 – 1374  Sonnet 131 [I’d sing of Love in such a novel f...  I’d sing of Love in such a novel fashion\nthat...
# poem/sonnet-102-if-no-love-o-god-what-fele-i-so              Petrarch       1304 – 1374  Sonnet 102 [If no love is, O God, what fele I ...  If no love is, O God, what fele I so?\n    And...
# poem/sonnet-101-ways-apt-and-new-sing-love-id-find           Petrarch       1304 – 1374  Sonnet 101 [Ways apt and new to sing of love I...  Ways apt and new to sing of love I’d find,\nFo...
# ...                                                               ...               ...                                                ...                                                ...
# poem/unquiet-grave                                          Anonymous               NaN                                  The Unquiet Grave  I\n\n'The wind doth blow today, my love,\n  An...
# poem/sonnet-7-soote-season-bud-and-bloom-forth-...       Henry Howard               NaN  Sonnet 7 [The soote season, that bud and bloom...  The soote season, that bud and bloom forth bri...
# 50399/earth-upon-earth                                      Anonymous               NaN                                   Earth Upon Earth  Earth took of earth, earth with woe,\nEarth ot...
# 51552/song-of-the-thunders                                  Anonymous               NaN                               Song of the Thunders  Naangodinong                 Sometimes\nnimbab...
# poem/sonnet-12-alas-so-all-things-now-do-hold-t...       Henry Howard               NaN  Sonnet 12 [Alas, so all things now do hold the...  Alas, so all things now do hold their peace,\n...
#
#                                                           form    form_group                                               tags                                        poem_source  \
# id
# 43926/the-canterbury-tales-general-prologue            couplet  stanza forms  ['The Body', 'The Mind', 'Love', 'Activities',...                                            Unknown
# 144612/where-did-the-handsome-beloved-go                ghazal   verse forms  ['Appeared in Poetry Magazine', 'Living', 'Mar...  Source:\n                        Poetry\n     ...
# poem/sonnet-131-id-sing-love-such-novel-fashion         sonnet   verse forms               ['Sonnet', 'Fathers', 'Translation']  From The Poetry of Petrarch by Petrarch, trans...
# poem/sonnet-102-if-no-love-o-god-what-fele-i-so         sonnet   verse forms  ['Sonnet', 'Heartache', 'Public Domain', 'Tran...   From Troilus and Criseyde, as translated by G...
# poem/sonnet-101-ways-apt-and-new-sing-love-id-find      sonnet   verse forms                        ['Sonnet', 'Public Domain']  Translated by Robert Guthrie Macgregor. This p...
# ...                                                        ...           ...                                                ...                                                ...
# poem/unquiet-grave                                      ballad   verse forms                        ['Ballad', 'Public Domain']                 This poem is in the public domain.
# poem/sonnet-7-soote-season-bud-and-bloom-forth-...      sonnet   verse forms              ['Sonnet', 'Public Domain', 'Summer']                 This poem is in the public domain.
# 50399/earth-upon-earth                              free verse        meters                           ['Nature', 'Free Verse']                                            Unknown
# 51552/song-of-the-thunders                          free verse        meters                ['Nature', 'Weather', 'Free Verse']  Source:\n                        Chippewa Musi...
# poem/sonnet-12-alas-so-all-things-now-do-hold-t...      sonnet   verse forms           ['Sonnet', 'Heartache', 'Public Domain']                 This poem is in the public domain.
#
#                                                                                             poem_link                                        author_link  pub_year  extracted_birth_year  \
# id
# 43926/the-canterbury-tales-general-prologue         https://www.poetryfoundation.org/poems/43926/t...  https://www.poetryfoundation.org/poets/geoffre...       NaN                   NaN
# 144612/where-did-the-handsome-beloved-go            https://www.poetryfoundation.org/poetrymagazin...  https://www.poetryfoundation.org/poets/jalal-a...       NaN                1207.0
# poem/sonnet-131-id-sing-love-such-novel-fashion     https://poets.org/poem/sonnet-131-id-sing-love...                    https://poets.org/poet/petrarch    2004.0                1304.0
# poem/sonnet-102-if-no-love-o-god-what-fele-i-so     https://poets.org/poem/sonnet-102-if-no-love-o...                    https://poets.org/poet/petrarch    1375.0                1304.0
# poem/sonnet-101-ways-apt-and-new-sing-love-id-find  https://poets.org/poem/sonnet-101-ways-apt-and...                    https://poets.org/poet/petrarch    1374.0                1304.0
# ...                                                                                               ...                                                ...       ...                   ...
# poem/unquiet-grave                                               https://poets.org/poem/unquiet-grave                   https://poets.org/poet/anonymous    1400.0                   NaN
# poem/sonnet-7-soote-season-bud-and-bloom-forth-...  https://poets.org/poem/sonnet-7-soote-season-b...                https://poets.org/poet/henry-howard    1374.0                   NaN
# 50399/earth-upon-earth                              https://www.poetryfoundation.org/poems/50399/e...                                                NaN       NaN                   NaN
# 51552/song-of-the-thunders                          https://www.poetryfoundation.org/poems/51552/s...                                                NaN       NaN                   NaN
# poem/sonnet-12-alas-so-all-things-now-do-hold-t...  https://poets.org/poem/sonnet-12-alas-so-all-t...                https://poets.org/poet/henry-howard       NaN                   NaN
#
#                                                     extracted_death_year   form_tags                                     theme_tags occasion_tags             collected_from  found_closed  found_open
# id
# 43926/the-canterbury-tales-general-prologue                       1400.0          []                                             []            []          Poetry Foundation          True        True
# 144612/where-did-the-handsome-beloved-go                          1273.0          []                                             []            []          Poetry Foundation         False       False
# poem/sonnet-131-id-sing-love-such-novel-fashion                   1374.0  ['Sonnet']                     ['Fathers', 'Translation']            []  Academy of American Poets         False        True
# poem/sonnet-102-if-no-love-o-god-what-fele-i-so                   1374.0  ['Sonnet']  ['Heartache', 'Public Domain', 'Translation']            []  Academy of American Poets          True        True
# poem/sonnet-101-ways-apt-and-new-sing-love-id-find                1374.0  ['Sonnet']                              ['Public Domain']            []  Academy of American Poets          True       False
# ...                                                                  ...         ...                                            ...           ...                        ...           ...         ...
# poem/unquiet-grave                                                   NaN  ['Ballad']                              ['Public Domain']            []  Academy of American Poets          True        True
# poem/sonnet-7-soote-season-bud-and-bloom-forth-...                   NaN  ['Sonnet']                              ['Public Domain']    ['Summer']  Academy of American Poets          True       False
# 50399/earth-upon-earth                                               NaN          []                                             []            []          Poetry Foundation          True       False
# 51552/song-of-the-thunders                                           NaN          []                                             []            []          Poetry Foundation         False       False
# poem/sonnet-12-alas-so-all-things-now-do-hold-t...                   NaN  ['Sonnet']                 ['Heartache', 'Public Domain']            []  Academy of American Poets          True       False
#
# [1636 rows x 19 columns]

# %%
# Out:
# found_open
# False    865
# True     771
# Name: count, dtype: int64

# %%
df_mem=pd.read_csv('../../poetry-eval/data/memorization_results.csv').drop('Unnamed: 0',axis=1)
df_mem = df_mem.rename(columns={'poem':'poem_id', 'prediction':'found'})
df_mem['found_closed'] = df_mem['found'].astype(bool)
df_mem_walsh = df_mem.merge(df_walsh, on='poem_id').set_index('poem_id')
df_mem_walsh

# %%
df_walsh2 = pd.concat([
    df_mem_walsh.assign(found_source='Memorized by closed models (Walsh et al)'),
    odf_walsh2.assign(found_source='Found in open model training data (Walsh et al)'),
])
df_walsh2

# %%
figdf5 = pd.concat([
    figdf4,
    df_walsh2
])
figdf5.groupby(['found_source','found']).size()

# %%
import plotnine as p9
p9.options.figure_size=8,6
p9.options.dpi=300
fig = p9.ggplot(figdf5, p9.aes('perc_rhyming_lines', color='found', fill='found'))
fig += p9.geom_density(alpha=.1)
fig+= p9.theme_minimal()
fig += p9.facet_wrap('found_source')
fig+= p9.theme(
    legend_position='bottom',
    plot_background=p9.element_rect(fill='white', color=None),  # Add white background
    panel_background=p9.element_rect(fill='white', color=None)  # Add white background to panels
)
fig+= p9.labs(
    y='Probability density',
    x='Percent of lines rhyming',
    color='Poem in LLM training data',
    fill='Poem in LLM training data',
    title='Poems in LLM training data are not disproportionately rhyming',
    # caption='Note: Given the first 5 lines of 10-20 line poems from poets born in each century, 1600-2000, LLMs are prompted to "complete" the poem.\nRhyme is measured by exact phoneme match in the rime of the final syllable (or syllables, if final syllable unstressed).\nPoems randomly sampled from Chadwyck-Healey poetry collections, with 600 poems for each model for each century.\nResults shown for actual poems as well as the LLM imitations. Poems "memorized" by the model are excluded.'
)
fig.save(os.path.expanduser('~/Dropbox/Prof/Data/fig.rhyme_distros_by_memorized2.png'))
fig
