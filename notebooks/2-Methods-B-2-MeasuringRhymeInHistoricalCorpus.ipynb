# %% [markdown]
# # Measuring rhyme in corpus

# %%
# !pip install -r ../requirements.txt
import sys
sys.path.append('../')
from generative_formalism import *
import plotnine as p9
pd.options.display.max_rows = 25
p9.options.dpi=300
p9.options.figure_size=(10,5)
# Out:
# LMDBHashStash(~/github/generative-formalism/data/stash/rhyme_for_txt/lmdb.hashstash.lz4+b64/data.db)

# %% [markdown]
# ## In paper sample

# %% [markdown]
# #### Sampled by period

# %%
documentation(get_rhyme_data_for_corpus_sampled_by_period_as_in_paper)
# Out:
# **`get_rhyme_data_for_corpus_sampled_by_period_as_in_paper`**
#
# ```md
# None
# ```
# ----

# %%
df_rhyme_for_corpus_sampled_by_period_as_in_paper = get_rhyme_data_for_corpus_sampled_by_period_as_in_paper()
df_rhyme_for_corpus_sampled_by_period_as_in_paper
# Out:
#                                 num_rhyming_lines num_perfectly_rhyming_lines num_lines                                 rhyming_line_pairs num_lines_prosodic perc_rhyming_lines  \
# id
# english-ed2/ep2438/Z300661875                35.0                        25.0      35.0  [('Ah! sweet were the days, and the nights and...               35.0              100.0
# english/pennecu1/Z200459978                  45.0                        35.0      50.0  [("A country mouse, upon a winter's day,", 'Me...               50.0               90.0
# english/wattsisa/Z300523040                  15.0                        14.0      16.0  [('There is beyond the sky', 'And holy childre...               16.0              93.75
# english/hardytho/Z200137433                  10.0                         8.0      16.0  [('I am under the bough;', 'Than I am now.', 0...               16.0               62.5
# ...

# %% [markdown]
# ### Sampled by rhyme annotation

# %%
documentation(get_rhyme_data_for_corpus_sampled_by_rhyme_as_in_paper)
# Out:
# **`get_rhyme_data_for_corpus_sampled_by_rhyme_as_in_paper`**
#
# ```md
# None
# ```
# ----

# %%
df_rhyme_for_corpus_sampled_by_rhyme_as_in_paper = get_rhyme_data_for_corpus_sampled_by_rhyme_as_in_paper()
df_rhyme_for_corpus_sampled_by_rhyme_as_in_paper
# Out:
#                               num_rhyming_lines num_perfectly_rhyming_lines num_lines                                 rhyming_line_pairs num_lines_prosodic perc_rhyming_lines  \
# id
# english-ed2/ep2438/Z300661875              35.0                        25.0      35.0  [('Ah! sweet were the days, and the nights and...               35.0              100.0
# english/pennecu1/Z200459978                45.0                        35.0      50.0  [("A country mouse, upon a winter's day,", 'Me...               50.0               90.0
# english/wattsisa/Z300523040                15.0                        14.0      16.0  [('There is beyond the sky', 'And holy childre...               16.0              93.75
# english/hardytho/Z200137433                10.0                         8.0      16.0  [('I am under the bough;', 'Than I am now.', 0...               16.0               62.5
# ...

# %% [markdown]
# ### Sampled by period/subcorpus

# %%
documentation(get_rhyme_data_for_corpus_sampled_by_rhyme_as_in_paper)
# Out:
# **`get_rhyme_data_for_corpus_sampled_by_rhyme_as_in_paper`**
#
# ```md
# None
# ```
# ----

# %%
df_rhyme_for_corpus_sampled_by_period_subcorpus_as_in_paper = get_rhyme_data_for_corpus_sampled_by_period_subcorpus_as_in_paper()
df_rhyme_for_corpus_sampled_by_period_subcorpus_as_in_paper
# Out:
#                                         num_rhyming_lines num_perfectly_rhyming_lines num_lines                                 rhyming_line_pairs num_lines_prosodic perc_rhyming_lines  \
# id
# c20-english/ep20152/Z200586158                        6.0                         2.0      12.0  [('As summer and pale', 'Of marvels frail.', 0...               12.0               50.0
# english/kerpeter/Z300410015                          13.0                        11.0      16.0  [('A Non such-sight (as it is said)', 'A Wife,...               16.0              81.25
# american/am1258/Z200196105                           12.0                         2.0      16.0  [('Of a gusty Autumn day,', 'Sighed his soul a...               16.0               75.0
# english/gilfilla/Z400379001                          23.0                        14.0      36.0  [('The storm is loud and high,', 'Hath gleamed...               36.0          63.888889
# ...

# %% [markdown]
# ## In replicated sample

# %% [markdown]
# #### Sampled by period

# %%
documentation(get_rhyme_data_for_corpus_sampled_by_period_as_replicated)
# Out:
# **`get_rhyme_data_for_corpus_sampled_by_period_as_replicated`**
#
# ```md
# None
# ```
# ----

# %%
df_rhyme_for_corpus_sampled_by_period_as_replicated = get_rhyme_data_for_corpus_sampled_by_period_as_replicated()
df_rhyme_for_corpus_sampled_by_period_as_replicated
# Out:
# * Loading period sample from /Users/rj416/github/generative-formalism/data/corpus_sample_by_period.replicated.csv.gz
#                                 num_rhyming_lines num_perfectly_rhyming_lines num_lines                                 rhyming_line_pairs num_lines_prosodic perc_rhyming_lines  \
# id
# english-ed2/ep2552/Z300670720                28.0                        24.0      32.0  [('He did not stand with open palm,', 'He did ...               32.0               87.5
# c20-english/car2302/Z200592139               24.0                         4.0      45.0  [('She told us: take a picture, and art postca...               45.0          53.333333
# english/keblejoh/Z200408216                  56.0                        44.0      68.0  [('O God of Mercy, God of Might,', 'How should...               68.0          82.352941
# ...

# %% [markdown]
# ### Sampled by rhyme annotation

# %%
documentation(get_rhyme_data_for_corpus_sampled_by_rhyme_as_replicated)
# Out:
# **`get_rhyme_data_for_corpus_sampled_by_rhyme_as_replicated`**
#
# ```md
# None
# ```
# ----

# %%
df_rhyme_for_corpus_sampled_by_rhyme_as_replicated = get_rhyme_data_for_corpus_sampled_by_rhyme_as_replicated()
df_rhyme_for_corpus_sampled_by_rhyme_as_replicated
# Out:
# * Loading rhyme sample from /Users/rj416/github/generative-formalism/data/corpus_sample_by_rhyme.replicated.csv.gz
#                               num_rhyming_lines num_perfectly_rhyming_lines num_lines                                 rhyming_line_pairs num_lines_prosodic perc_rhyming_lines  \
# id
# english-ed2/ep2438/Z300661875              35.0                        25.0      35.0  [('Ah! sweet were the days, and the nights and...               35.0              100.0
# english/pennecu1/Z200459978                45.0                        35.0      50.0  [("A country mouse, upon a winter's day,", 'Me...               50.0               90.0
# english/wattsisa/Z300523040                15.0                        14.0      16.0  [('There is beyond the sky', 'And holy childre...               16.0              93.75
# ...

# %% [markdown]
# ### Sampled by period/subcorpus

# %%
documentation(get_rhyme_data_for_corpus_sampled_by_rhyme_as_replicated)
# Out:
# **`get_rhyme_data_for_corpus_sampled_by_rhyme_as_replicated`**
#
# ```md
# None
# ```
# ----

# %%
df_rhyme_for_corpus_sampled_by_period_subcorpus_as_replicated = get_rhyme_data_for_corpus_sampled_by_rhyme_as_replicated()
df_rhyme_for_corpus_sampled_by_period_subcorpus_as_replicated
# Out:
# * Loading rhyme sample from /Users/rj416/github/generative-formalism/data/corpus_sample_by_rhyme.replicated.csv.gz
#                               num_rhyming_lines num_perfectly_rhyming_lines num_lines                                 rhyming_line_pairs num_lines_prosodic perc_rhyming_lines  \
# id
# english-ed2/ep2438/Z300661875              35.0                        25.0      35.0  [('Ah! sweet were the days, and the nights and...               35.0              100.0
# english/pennecu1/Z200459978                45.0                        35.0      50.0  [("A country mouse, upon a winter's day,", 'Me...               50.0               90.0
# english/wattsisa/Z300523040                15.0                        14.0      16.0  [('There is beyond the sky', 'And holy childre...               16.0              93.75
# ...
