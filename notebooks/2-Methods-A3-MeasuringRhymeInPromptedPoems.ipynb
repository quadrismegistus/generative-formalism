# %% [markdown]
# # Rhyme

# %%
# !pip install -r ../requirements.txt
import sys
sys.path.append('../')
from generative_formalism import *

# %% [markdown]
# ## In paper sample

# %%
documentation(get_rhyme_for_prompted_poems_as_in_paper)
# Out:
# **`get_rhyme_for_prompted_poems_as_in_paper`**
#
# ```md
# None
# ```
# ----

# %%
df_rhyme_for_prompted_poems_as_in_paper = get_rhyme_for_prompted_poems_as_in_paper(verbose=True)
df_rhyme_for_prompted_poems_as_in_paper
# Out:
# * Collecting genai rhyme promptings as used in paper
#   * Collecting from /Users/rj416/github/generative-formalism/data/corpus_genai_promptings.csv.gz
#   * 17,988 generated responses
#   * 16,935 unique responses
#   * 16,871 unique poems
#   * 23 unique prompts
#   * 3 unique prompt types
# * Getting rhymes for sample: 100%|██████████| 13838/13838 [00:03<00:00, 4231.26it/s]
#           num_rhyming_lines  num_perfectly_rhyming_lines  num_lines                                 rhyming_line_pairs  num_lines_prosodic  perc_rhyming_lines  perc_perfectly_rhyming_lines  \
# id
# f07b80fa               18.0                         16.0       20.0  [(The sun dips low, the stars arise,, A canvas...                20.0           90.000000                     80.000000
# 6288f980               10.0                          8.0       16.0  [(Soft murmurs of the passing breeze., Dispell...                16.0           62.500000                     50.000000
# ...

# %% [markdown]
# ## In replicated sample

# %%
documentation(get_rhyme_for_prompted_poems_as_replicated)
# Out:
# **`get_rhyme_for_prompted_poems_as_replicated`**
#
# ```md
# None
# ```
# ----

# %%
df_rhyme_for_prompted_poems_as_replicated = get_rhyme_for_prompted_poems_as_replicated(verbose=True)
df_rhyme_for_prompted_poems_as_replicated
# Out:
# * Collecting genai rhyme promptings as replicated here
#   * Collecting from /Users/rj416/github/generative-formalism/data/stash/genai_rhyme_prompts/lmdb.hashstash.lz4+b64/data.db
#   * 13 generated poems
#   * 13 generated responses
#   * 13 unique responses
#   * 13 unique poems
#   * 10 unique prompts
#   * 3 unique prompt types
# * Getting rhymes for sample: 100%|██████████| 12/12 [00:00<00:00, 2721.22it/s]
#     index  num_rhyming_lines  num_perfectly_rhyming_lines  num_lines                                 rhyming_line_pairs  num_lines_prosodic  perc_rhyming_lines  perc_perfectly_rhyming_lines  \
# 0       4                 12                           10         14  [(The years slip by, a steady, silent flow,, W...                  14           85.714286                     71.428571
# 1       0                 11                           10         14  [(With courage in their heart and steel in han...                  14           78.571429                     71.428571
# ...
