# %% [markdown]
# # Collecting rhyme prompting data

# %%
import sys
sys.path.append('../')
from generative_formalism import *

# %% [markdown]
# ## Loading data
#
# ### Pre/post-processing

# %%
documentation(preprocess_rhyme_promptings)
documentation(postprocess_rhyme_promptings)
# Out:
# **`preprocess_rhyme_promptings`**
#
# ```md
# Preprocess rhyme promptings data.
#
#     This function preprocesses rhyme promptings data from legacy pickle and JSON files,
#     combines them, and saves to CSV format.
#
#     Args:
#         overwrite (bool, optional): Whether to overwrite existing processed data.
#             Defaults to False.
#         save_to (str, optional): Path to save the processed data.
#             Defaults to PATH_GENAI_PROMPTS_IN_PAPER.
#
#     Returns:
#         pd.DataFrame: Preprocessed data as a dataframe.
#
# ```
# ----
# **`postprocess_rhyme_promptings`**
#
# ```md
# Postprocess rhyme promptings data.
#
#     This function postprocesses rhyme promptings data by cleaning the text,
#     setting the prompt type, and filtering the data by prompt and model.
#
#     Args:
#         df_prompts (pd.DataFrame): Input DataFrame containing rhyme promptings data.
#         prompts (list, optional): List of prompts to include.
#             Defaults to PROMPT_LIST.
#         models (list, optional): List of models to include.
#             Defaults to MODEL_LIST.
#         min_lines (int, optional): Minimum number of lines for filtering.
#             Defaults to MIN_NUM_LINES.
#         max_lines (int, optional): Maximum number of lines for filtering.
#             Defaults to MAX_NUM_LINES.
#         save_to (str, optional): Path to save the processed data.
#             Defaults to None.
#         overwrite (bool, optional): Whether to overwrite existing processed data.
#             Defaults to False.
#         display (bool, optional): Whether to display the processed data.
#             Defaults to False.
#         verbose (bool, optional): Whether to print verbose output.
#             Defaults to True.
#         **display_kwargs: Additional keyword arguments passed to display_rhyme_promptings.
#
#     Returns:
#         pd.DataFrame: Postprocessed data as a dataframe.
#
# ```
# ----

# %% [markdown]
# ### Data used in paper

# %%
df_genai_rhyme_promptings_as_in_paper = get_genai_rhyme_promptings_as_in_paper(display=True,verbose=True)
df_genai_rhyme_promptings_as_in_paper
# Out:
# * Collecting genai rhyme promptings as used in paper
#   * Collecting from /Users/rj416/github/generative-formalism/data/data_as_in_paper/genai_rhyme_promptings.csv.gz
# ['id', 'model', 'temperature', 'prompt', 'prompt_type', 'response', 'num_lines', 'id_hash', 'rhyme']
#   * 13,849 generated responses
#   * 13,700 unique responses
#   * 13,700 unique poems
#   * 23 unique prompts
#   * 3 unique prompt types
#           id_hash   prompt_type                                             prompt                    model  temperature                                                txt  num_lines
# id
# 72b3a92f      187      DO_rhyme                 Write a long poem that does rhyme.      ollama/llama3.1:70b     0.700000  In realms of dreams, where shadows play,\nA my...         48
# cca470b9      252  do_NOT_rhyme         Write a poem in the style of Walt Whitman.             ollama/olmo2     0.700000  Oh, vast and boundless universe, so wide and f...         20
# e2dc6a00      487      DO_rhyme                   Write a poem in heroic couplets.       ollama/llama3.1:8b     0.700000  In twilight's hush, where shadows dance and pl...         10
# 13390157      545   MAYBE_rhyme                                      Write a poem.  claude-3-haiku-20240307     0.794582  The gentle breeze, a soft caress,\nCarries sec...         16
# bffaf609      552   MAYBE_rhyme                                 Write a long poem.       ollama/llama3.1:8b     0.700000  In twilight's hush, where shadows dance and pl...         44
# ...           ...           ...                                                ...                      ...          ...                                                ...        ...
# 620328dd   999549   MAYBE_rhyme           Write a poem in stanzas of 4 lines each.   deepseek/deepseek-chat     0.700000  Beneath the sky so vast and blue,  \nThe whisp...         20
# 83708d56   999596  do_NOT_rhyme             Write a long poem that does NOT rhyme.             ollama/olmo2     0.700000  In a land of data, vast and wide,\nWhere algor...         32
# 9bd3cc4b   999716   MAYBE_rhyme                                Write a short poem.            gpt-3.5-turbo     0.640020  In the quiet of the night,  \nI hear the whisp...         12
# 63d2d100   999735      DO_rhyme                   Write a poem in heroic couplets.              gpt-4-turbo     0.971985  Upon the glade where shadows dance at night,\n...         32
# 8532c5ce   999824  do_NOT_rhyme  Write a poem (with 20+ lines) that does NOT rh...             ollama/olmo2     0.700000  In the dawn of morning light, where shadows so...         28
#
# [13838 rows x 7 columns]

# %% [markdown]
# ### Data replicated here

# %%
documentation(get_genai_rhyme_promptings_as_replicated)
# Out:
# **`get_genai_rhyme_promptings_as_replicated`**
#
# ```md
#
#     Get genai rhyme promptings as replicated in this implementation.
#
#     This function retrieves the rhyme promptings data that was generated
#     and replicated in this codebase, as opposed to the original data
#     used in the paper. It processes the data through the same postprocessing
#     pipeline but uses the replicated suffix for output files.
#
#     Args:
#         *args: Variable length argument list passed to postprocess_rhyme_promptings.
#         verbose (bool, optional): Whether to print verbose output during processing.
#             Defaults to True.
#         **kwargs: Additional keyword arguments passed to postprocess_rhyme_promptings.
#             Common kwargs include:
#             - prompts: List of prompts to process (defaults to PROMPT_LIST)
#             - models: List of models to process (defaults to MODEL_LIST)
#             - min_lines: Minimum number of lines per poem (defaults to MIN_NUM_LINES)
#             - max_lines: Maximum number of lines per poem (defaults to MAX_NUM_LINES)
#             - save_to: Path to save processed data
#             - overwrite: Whether to overwrite existing files
#
#     Returns:
#         pd.DataFrame: Processed rhyme promptings data with replicated suffix
#         applied to output files. Contains the same structure as the paper
#         data but generated from the current implementation's stash.
#
#     Note:
#         This function uses REPLICATED_SUFFIX for output file naming to
#         distinguish it from the original paper data. The underlying data
#         comes from get_stash_df_poems() which contains the replicated
#         generation results.
#
# ```
# ----

# %%
df_genai_rhyme_promptings_as_replicated = get_genai_rhyme_promptings_as_replicated(display=True)
df_genai_rhyme_promptings_as_replicated
# Out:
# * Collecting genai rhyme promptings as replicated here
#   * Collecting from /Users/rj416/github/generative-formalism/data/stash/genai_rhyme_prompts/lmdb.hashstash.lz4+b64/data.db
#   * 23 generated poems
#   * 23 generated responses
#   * 23 unique responses
#   * 23 unique poems
#   * 11 unique prompts
#   * 3 unique prompt types
#           id  id_hash   prompt_type                                             prompt                    model  temperature                                                txt  num_lines
# 0   f3f39808    13667      DO_rhyme                   Write a poem in heroic couplets.  claude-3-haiku-20240307          0.7  In times of strife, when darkness casts its pa...         14
# 20  80c95dee    32606  do_NOT_rhyme  Write a poem (with 20+ lines) that does NOT rh...   deepseek/deepseek-chat          0.7  The morning arrives without ceremony.\nA pale ...         26
# 5   0d013c0b   109738  do_NOT_rhyme                  Write a poem that does NOT rhyme.  claude-3-haiku-20240307          0.7  Gentle breeze caresses my face,\nRustling leav...         12
# 3   f4942127   139227      DO_rhyme                             Write an rhyming poem.   claude-3-opus-20240229          0.7  In fields of green and skies of blue,\nWhere f...         16
# 22  b2962b34   140542   MAYBE_rhyme                                 Write a long poem.  claude-3-haiku-20240307          0.7  In the vast, endless expanse of the universe,\...         40
# 6   4543d686   156472  do_NOT_rhyme                  Write a poem that does NOT rhyme.  claude-3-haiku-20240307          0.7  Whispers in the wind,\nEchoing through the tre...         16
# 9   fd66b1ae   193400  do_NOT_rhyme                  Write a poem that does NOT rhyme.  claude-3-haiku-20240307          0.7  Whispers in the wind,\nEchoes of a forgotten t...         12
# 16  43362055   220494  do_NOT_rhyme             Write a long poem that does NOT rhyme.  claude-3-haiku-20240307          0.7  The whispers on the wind carry tales untold,\n...         28
# 11  a3505fe5   243032      DO_rhyme                             Write an rhyming poem.   deepseek/deepseek-chat          0.7  The sun has climbed the morning's stair,\nThe ...         16
# 18  9aa04551   270558      DO_rhyme         Write a poem (with 20+ lines) that rhymes.   deepseek/deepseek-chat          0.7  The sun departs with one last streak of gold,\...         24
# 12  996aa64e   418512      DO_rhyme         Write a poem (with 20+ lines) that rhymes.  claude-3-haiku-20240307          0.7  The chords they strike, a timeless tune,\nEcho...         20
# 7   9d54964d   445060  do_NOT_rhyme                  Write a poem that does NOT rhyme.  claude-3-haiku-20240307          0.7  Whispers in the wind,\nEchoes of a forgotten p...         12
# 13  8ee1ed92   464072      DO_rhyme  Write an ryhmed poem in the style of Shakespea...  claude-3-haiku-20240307          0.7  When summer's bloom has faded from the land,\n...         14
# 2   eef6f4e9   490494  do_NOT_rhyme                  Write a poem that does NOT rhyme.   deepseek/deepseek-chat          0.7  The sun is a pale coin\nbehind the morning's g...         17
# 17  961d1e30   598601      DO_rhyme                   Write a poem in heroic couplets.   deepseek/deepseek-chat          0.7  When Phoebus drives his chariot from the east,...         22
# 8   da0399d7   612732  do_NOT_rhyme                  Write a poem that does NOT rhyme.  claude-3-haiku-20240307          0.7  Beneath the endless sky,\nClouds drift, a sile...         12
# 1   3aa11730   705133  do_NOT_rhyme                  Write a poem that does NOT rhyme.   deepseek/deepseek-chat          0.7  The sun climbs the morning’s pale ladder.\nA s...         24
# 4   aba1b614   729530  do_NOT_rhyme                  Write a poem that does NOT rhyme.  claude-3-haiku-20240307          0.7  Soft and gentle, it caresses my skin,\nA sooth...         12
# 19  3e08461d   797851   MAYBE_rhyme                                      Write a poem.  claude-3-haiku-20240307          0.7  The whisper of the wind,\nCaressing my face wi...         16
# 15  06bcd8d7   910930   MAYBE_rhyme           Write a poem in stanzas of 4 lines each.   deepseek/deepseek-chat          0.7  The sun descends in robes of gold,\nAnd paints...         16
# 14  005b1d76   929975  do_NOT_rhyme                       Write a poem in blank verse.  claude-3-haiku-20240307          0.7  The years slip by, a steady, silent flow,\nEac...         14
# 10  ff3553ac   940007  do_NOT_rhyme                  Write a poem that does NOT rhyme.  claude-3-haiku-20240307          0.7  Whispers in the wind,\nEchoing through the tre...         20

# %% [markdown]
# ### Aggregating paper + replicated data

# %%
# All together
df_all_rhyme_promptings = get_all_genai_rhyme_promptings(display=True)
df_all_rhyme_promptings
# Out:
# * Collecting genai rhyme promptings as used in paper
#   * Collecting from /Users/rj416/github/generative-formalism/data/data_as_in_paper/genai_rhyme_promptings.csv.gz
# ['id', 'model', 'temperature', 'prompt', 'prompt_type', 'response', 'num_lines', 'id_hash', 'rhyme']
#   * 13,849 generated responses
#   * 13,700 unique responses
#   * 13,700 unique poems
#   * 23 unique prompts
#   * 3 unique prompt types
#
# * Collecting genai rhyme promptings as replicated here
#   * Collecting from /Users/rj416/github/generative-formalism/data/stash/genai_rhyme_prompts/lmdb.hashstash.lz4+b64/data.db
#   * 23 generated poems
#   * 23 generated responses
#   * 23 unique responses
#   * 23 unique poems
#   * 11 unique prompts
#   * 3 unique prompt types
#           id_hash   prompt_type                                      prompt                    model  temperature                                                txt  num_lines        id
# 72b3a92f      187      DO_rhyme          Write a long poem that does rhyme.      ollama/llama3.1:70b     0.700000  In realms of dreams, where shadows play,\nA my...         48       NaN
# cca470b9      252  do_NOT_rhyme  Write a poem in the style of Walt Whitman.             ollama/olmo2     0.700000  Oh, vast and boundless universe, so wide and f...         20       NaN
# e2dc6a00      487      DO_rhyme            Write a poem in heroic couplets.       ollama/llama3.1:8b     0.700000  In twilight's hush, where shadows dance and pl...         10       NaN
# 13390157      545   MAYBE_rhyme                               Write a poem.  claude-3-haiku-20240307     0.794582  The gentle breeze, a soft caress,\nCarries sec...         16       NaN
# bffaf609      552   MAYBE_rhyme                          Write a long poem.       ollama/llama3.1:8b     0.700000  In twilight's hush, where shadows dance and pl...         44       NaN
# ...           ...           ...                                         ...                      ...          ...                                                ...        ...       ...
# 4          729530  do_NOT_rhyme           Write a poem that does NOT rhyme.  claude-3-haiku-20240307     0.700000  Soft and gentle, it caresses my skin,\nA sooth...         12  aba1b614
# 19         797851   MAYBE_rhyme                               Write a poem.  claude-3-haiku-20240307     0.700000  The whisper of the wind,\nCaressing my face wi...         16  3e08461d
# 15         910930   MAYBE_rhyme    Write a poem in stanzas of 4 lines each.   deepseek/deepseek-chat     0.700000  The sun descends in robes of gold,\nAnd paints...         16  06bcd8d7
# 14         929975  do_NOT_rhyme                Write a poem in blank verse.  claude-3-haiku-20240307     0.700000  The years slip by, a steady, silent flow,\nEac...         14  005b1d76
# 10         940007  do_NOT_rhyme           Write a poem that does NOT rhyme.  claude-3-haiku-20240307     0.700000  Whispers in the wind,\nEchoing through the tre...         20  ff3553ac
#
# [13860 rows x 8 columns]
