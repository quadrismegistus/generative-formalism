# %% [markdown]
# # Collecting rhyme prompting data

# %%
import sys
sys.path.append('../')
from generative_formalism import *

# %%
get_stash_df_poems()
# Out:
#   * Collecting from /Users/ryan/github/generative-formalism/data/stash/genai_rhyme_prompts/pairtree.hashstash.raw+b64/data.db
#   * 2 generated poems
#                             model                             prompt  temperature system_prompt                                                txt   prompt_type  id_hash
# id
# 29249854  claude-3-haiku-20240307  Write a poem that does NOT rhyme.          0.7          None  Here is a poem that does not rhyme:\n\nWhisper...  do_NOT_rhyme   285702
# f1a90cfb  claude-3-haiku-20240307  Write a poem that does NOT rhyme.          0.7          None  Here is a poem that does not rhyme:\n\nBeneath...  do_NOT_rhyme   317834

# %% [markdown]
# ## Loading data
#
# ### Pre/post-processing

# %%
# Docs
documentation(preprocess_rhyme_promptings)
documentation(postprocess_rhyme_promptings)
# Out:
# ##### `preprocess_rhyme_promptings`
#
# ```md
# Preprocess rhyme promptings data.
#
#     This function preprocesses rhyme promptings data from legacy pickle and JSON files,
#     combines them, and saves to CSV format.
#
#     Args:
#         overwrite (bool, optional): Whether to overwrite existing processed data.
#             Defaults to False.
#         save_to (str, optional): Path to save the processed data.
#             Defaults to PATH_GENAI_PROMPTS_IN_PAPER.
#
#     Returns:
#         pd.DataFrame: Preprocessed data as a dataframe.
#
# ```
# ----
# ##### `postprocess_rhyme_promptings`
#
# ```md
# Postprocess rhyme promptings data.
#
#     This function postprocesses rhyme promptings data by cleaning the text,
#     setting the prompt type, and filtering the data by prompt and model.
#
#     Args:
#         df_prompts (pd.DataFrame): Input DataFrame containing rhyme promptings data.
#         prompts (list, optional): List of prompts to include.
#             Defaults to PROMPT_LIST.
#         models (list, optional): List of models to include.
#             Defaults to MODEL_LIST.
#         min_lines (int, optional): Minimum number of lines for filtering.
#             Defaults to MIN_NUM_LINES.
#         max_lines (int, optional): Maximum number of lines for filtering.
#             Defaults to MAX_NUM_LINES.
#         save_to (str, optional): Path to save the processed data.
#             Defaults to None.
#         overwrite (bool, optional): Whether to overwrite existing processed data.
#             Defaults to False.
#         display (bool, optional): Whether to display the processed data.
#             Defaults to False.
#         verbose (bool, optional): Whether to print verbose output.
#             Defaults to True.
#         **display_kwargs: Additional keyword arguments passed to display_rhyme_promptings.
#
#     Returns:
#         pd.DataFrame: Postprocessed data as a dataframe.
#
# ```
# ----

# %% [markdown]
# ### Data used in paper

# %%
df_genai_rhyme_promptings_as_in_paper = get_genai_rhyme_promptings(
    as_in_paper=True,
    display=False, 
    verbose=True
)
df_genai_rhyme_promptings_as_in_paper
# Out:
#   * 13,849 generated responses
#   * 13,700 unique poems
#   * 23 unique prompts
#   * 3 unique prompt types
#          data_source  id_hash   prompt_type                                             prompt                    model  temperature                                                txt  num_lines
# id
# 708c1799    in_paper       58      DO_rhyme         Write a poem (with 20+ lines) that rhymes.             ollama/olmo2     0.700000  In a land where dreams and reality align,\nA p...         20
# 7f230697    in_paper      121   MAYBE_rhyme               Write a poem in groups of two lines.   claude-3-opus-20240229     0.442412  In fields of gold and amber hues,\nThe sun-kis...         12
# c89c9d0b    in_paper      137      DO_rhyme                             Write an rhyming poem.         ollama/olmo2:13b     0.700000  In the land of dreams and starlit skies,\nWher...         24
# c6a41047    in_paper      260  do_NOT_rhyme                  Write a poem that does NOT rhyme.            gpt-3.5-turbo     0.693997  In the stillness of the night\nI find solace i...         20
# 4f004d48    in_paper      327      DO_rhyme  Write an ryhmed poem in the style of Shakespea...            gpt-3.5-turbo     1.025238  Oh shall I compare thee to a summer's day?\nTh...         14
# ...              ...      ...           ...                                                ...                      ...          ...                                                ...        ...
# 20170229    in_paper   999772   MAYBE_rhyme                     Write a poem (with 20+ lines).      ollama/llama3.1:70b     0.700000  In twilight's hush, where shadows play,\nAmids...         24
# 55a36f94    in_paper   999779   MAYBE_rhyme           Write a poem in stanzas of 4 lines each.  claude-3-haiku-20240307     0.899761  In the depths of the night,\nThe stars shine s...         16
# 0c54c76a    in_paper   999894  do_NOT_rhyme                            Write an unrhymed poem.         ollama/olmo2:13b     0.700000  In the quiet of the morning's embrace,\nBefore...         16
# 330d9c9f    in_paper   999931  do_NOT_rhyme  Write a poem (with 20+ lines) that does NOT rh...              gpt-4-turbo     0.704555  In the quiet hours of morning, light unfolds\n...         32
# d0c44a44    in_paper   999989      DO_rhyme                   Write a poem in heroic couplets.              gpt-4-turbo     0.276883  In verdant fields where sun and shadow play,\n...         24
#
# [13838 rows x 8 columns]

# %% [markdown]
# ### Data replicated here

# %%
df_genai_rhyme_promptings_as_replicated = get_genai_rhyme_promptings(
    as_in_paper=False,
    as_replicated=True,
    display=False, 
    verbose=True
)
df_genai_rhyme_promptings_as_replicated
# Out:
# * Collecting genai rhyme promptings as replicated here
#   * Collecting from /Users/ryan/github/generative-formalism/data/stash/genai_rhyme_prompts/pairtree.hashstash.raw+b64/data.db
#   * 2 generated poems
#   * 2 generated responses
#   * 2 unique poems
#   * 1 unique prompts
#   * 1 unique prompt types
#          data_source  id_hash   prompt_type                             prompt                    model  temperature                                                txt  num_lines
# id
# bd358e87  replicated   316779  do_NOT_rhyme  Write a poem that does NOT rhyme.  claude-3-haiku-20240307          0.7  Beneath the endless sky,\nI stand, alone and s...         12
# da214187  replicated   848751  do_NOT_rhyme  Write a poem that does NOT rhyme.  claude-3-haiku-20240307          0.7  Whispers of the wind,\nCaressing the trees,\nR...         12

# %% [markdown]
# ### Aggregating paper + replicated data

# %%
# All together
df_all_rhyme_promptings = get_genai_rhyme_promptings(
    as_in_paper=True,
    as_replicated=True,
    display=False,
    verbose=True
)

describe_qual(df_all_rhyme_promptings.data_source)
df_all_rhyme_promptings
# Out:
# * Collecting genai rhyme promptings as replicated here
#   * Collecting from /Users/ryan/github/generative-formalism/data/stash/genai_rhyme_prompts/pairtree.hashstash.raw+b64/data.db
#   * 2 generated poems
#   * 13,851 generated responses
#   * 13,702 unique poems
#   * 23 unique prompts
#   * 3 unique prompt types
# * Breakdown for data_source
# in_paper      13838
# replicated        2
#          data_source  id_hash   prompt_type                                             prompt                    model  temperature                                                txt  num_lines
# id
# 708c1799    in_paper       58      DO_rhyme         Write a poem (with 20+ lines) that rhymes.             ollama/olmo2     0.700000  In a land where dreams and reality align,\nA p...         20
# 7f230697    in_paper      121   MAYBE_rhyme               Write a poem in groups of two lines.   claude-3-opus-20240229     0.442412  In fields of gold and amber hues,\nThe sun-kis...         12
# c89c9d0b    in_paper      137      DO_rhyme                             Write an rhyming poem.         ollama/olmo2:13b     0.700000  In the land of dreams and starlit skies,\nWher...         24
# c6a41047    in_paper      260  do_NOT_rhyme                  Write a poem that does NOT rhyme.            gpt-3.5-turbo     0.693997  In the stillness of the night\nI find solace i...         20
# 4f004d48    in_paper      327      DO_rhyme  Write an ryhmed poem in the style of Shakespea...            gpt-3.5-turbo     1.025238  Oh shall I compare thee to a summer's day?\nTh...         14
# ...              ...      ...           ...                                                ...                      ...          ...                                                ...        ...
# 20170229    in_paper   999772   MAYBE_rhyme                     Write a poem (with 20+ lines).      ollama/llama3.1:70b     0.700000  In twilight's hush, where shadows play,\nAmids...         24
# 55a36f94    in_paper   999779   MAYBE_rhyme           Write a poem in stanzas of 4 lines each.  claude-3-haiku-20240307     0.899761  In the depths of the night,\nThe stars shine s...         16
# 0c54c76a    in_paper   999894  do_NOT_rhyme                            Write an unrhymed poem.         ollama/olmo2:13b     0.700000  In the quiet of the morning's embrace,\nBefore...         16
# 330d9c9f    in_paper   999931  do_NOT_rhyme  Write a poem (with 20+ lines) that does NOT rh...              gpt-4-turbo     0.704555  In the quiet hours of morning, light unfolds\n...         32
# d0c44a44    in_paper   999989      DO_rhyme                   Write a poem in heroic couplets.              gpt-4-turbo     0.276883  In verdant fields where sun and shadow play,\n...         24
#
# [13840 rows x 8 columns]
