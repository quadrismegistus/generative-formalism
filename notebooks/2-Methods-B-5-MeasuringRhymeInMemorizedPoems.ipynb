# %% [markdown]
# # Rhyme

# %%
# !pip install -r ../requirements.txt
import sys
sys.path.append('../')
from generative_formalism import *

# %% [markdown]
# ## In paper sample

# %%
documentation(get_rhyme_for_completed_poems_as_in_paper)
# Out:
# **`get_rhyme_for_completed_poems_as_in_paper`**
#
# ```md
# None
# ```
# ----

# %%
df_rhyme_for_completed_poems_as_in_paper = get_rhyme_for_completed_poems_as_in_paper(verbose=True, force=False)
df_rhyme_for_completed_poems_as_in_paper
# Out:
# * Computing line similarity
# ...
# * Filtering out recognized completions: 100%|██████████| 21130/21130 [00:02<00:00, 8392.34it/s]
# * Filtered out 169 recognized poems
# * Converting to poem txt format (keeping first lines from original poem)
# * Getting rhymes for sample: 100%|██████████| 20961/20961 [00:04<00:00, 5159.98it/s]
#                                          id_human                   model  first_n_lines        date  keep_first_n_lines  num_rhyming_lines  num_perfectly_rhyming_lines  num_lines  \
# id
# 38fac30a               american/am1252/Z400194639     ollama/olmo2:latest              5  2025-03-16                True               14.0                          9.0       14.0
# 3f3044df              english/sbgamble/Z200491041     ollama/olmo2:latest              5  2025-03-16                True               16.0                          8.0       16.0
# ...

# %% [markdown]
# ## In replicated sample

# %%
documentation(get_rhyme_for_completed_poems_as_replicated)
# Out:
# **`get_rhyme_for_completed_poems_as_replicated`**
#
# ```md
# None
# ```
# ----

# %%
# df_rhyme_for_completed_poems_as_replicated = get_rhyme_for_completed_poems_as_replicated(verbose=True)
# df_rhyme_for_completed_poems_as_replicated

# %%
# Out:
# * Computing line similarity
# 100%|██████████| 326862/326862 [00:03<00:00, 94783.33it/s]
# * Filtered out 169 recognized poems
# * Converting to poem txt format (keeping first lines from original poem)
#                                                                                                                id_hash                                                txt  num_lines
# id_human                        model                    first_n_lines date       id       keep_first_n_lines
# english/arminrob/Z300263156     gpt-3.5-turbo            5             2025-03-24 000098c6 True                 263181  I cannot tell for certain, yet Isle guess.\nYo...         12
# english/heywoodt/Z200396007     ollama/olmo2:latest      5             2025-03-16 0004444f True                 655041  Excellent Princes may you ever be,\nAs great a...         20
# ...

# %%
df_smpl_w_rhyme_data = get_rhyme_for_sample(df_smpl)
df_smpl_w_rhyme_data
# Out:
#   4%|▍         | 824/20961 [00:55<23:15, 14.43it/s]
