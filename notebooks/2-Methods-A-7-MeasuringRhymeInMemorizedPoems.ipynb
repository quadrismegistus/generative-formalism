# %% [markdown]
# # Rhyme

# %%
# !pip install -r ../requirements.txt
import sys
sys.path.append('../')
from generative_formalism import *

# %%
df = get_all_memorization_data()
df
# Out:
# * Preprocessing from /Users/ryan/github/generative-formalism/data/raw/antoniak-et-al
# * Preprocessing Antoniak et al. memorization data from /Users/ryan/github/generative-formalism/data/raw/antoniak-et-al
# * Writing to /Users/ryan/github/generative-formalism/data/data.antoniak_et_al_memorization_results.csv.gz
# * Loading legacy genai rhyme completions from {PATH_REPO}/data/corpus_genai_rhyme_completions.csv.gz
# 100%|██████████| 326862/326862 [00:04<00:00, 76394.76it/s]
# * Converting to poem txt format (keeping first lines from original poem)
# * Writing to /Users/ryan/github/generative-formalism/data/data.all_memorization_data.csv.gz
# * Breakdown for poems found by corpus and source
#                                    count
# found_corpus   found_source found
# antoniak-et-al closed       False   2330
#                             True    1723
#                open         False   2294
#                             True    1759
# chadwyck       closed       False  11227
# ...

# %%
df_mem_rhyme = get_rhyme_for_sample(df, with_sample=True)
df_mem_rhyme
# Out:
# * Getting rhymes for sample:   6%|▋         | 1555/24039 [01:19<20:59, 17.85it/s]
